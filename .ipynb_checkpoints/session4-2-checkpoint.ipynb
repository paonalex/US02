# %%
import spacy
import math
import re

# %%
import en_core_web_sm
#import en_core_web_md
import en_core_web_lg

nlp1 = en_core_web_sm.load()
#nlp2 = en_core_web_md.load()
nlp3 = en_core_web_lg.load()

# %%
doc = nlp1(u"Apple is looking at buying U.K. startup for $1 billion. Bran Stark is a boy.")
for token in doc:
   print(token.lemma_, token.text) 
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Apple Apple
# be is
# look looking
# at at
# buy buying
# U.K. U.K.
# startup startup
# for for
# $ $
# 1 1
# billion billion
# . .
# Bran Bran
# Stark Stark
# be is
# a a
# boy boy
# . .
# Apple 0 5 ORG
# U.K. 27 31 GPE
# $1 billion 44 54 MONEY
# Stark 61 66 PERSON

# %%
def union_entities(listA, listB):
    result = listA
    for ent_b,y1,y2 in listB:
        overlap = False
        for ent_a,x1,x2 in listA:
            if x1 <= y2 and y1 <= x2: # overlap
                overlap = True
                if (y2-y1) > (x2-x2): # the largest entity is B
                    result.remove((ent_a,x1,x2))
                    result.append((ent_b,y1,y2))
                break
        if not overlap:
            result.append((ent_b,y1,y2))
    return result

with open('books/GOT1.txt') as fp:
    book = fp.read()
    chapters = book.split('\n\n\n\n\n')
    for i in range(0,len(chapters)):
        name =[word for word in chapters[i].split('\n') if len(word.strip())>0][0]
        print(i+1,name.title())
        chapter = ' '.join([word.replace('\t','').replace('"','') for word in chapters[i].split('\n') if len(word.strip())>0][1:])
        
        doc1 = nlp1(chapter)
        doc2 = nlp3(chapter)
        sm = []
        lg = []
        for ent in doc1.ents:
            if ent.label_ == 'PERSON':
                sm.append((ent.text, ent.start_char, ent.end_char))
        for ent in doc2.ents:
            if ent.label_ == 'PERSON':
                lg.append((ent.text, ent.start_char, ent.end_char))
        
        entities = union_entities(sm,lg)  
        print(len(entities))
# Out:
# 1 Prologue
# 104
# 2 Bran
# 118
# 3 Catelyn
# 89
# 4 Daenerys
# 176
# 5 Eddard
# 181
# 6 Jon
# 145
# 7 Catelyn
# 202
# 8 Arya
# 190
# 9 Bran
# 93
# 10 Tyrion
# 106
# 11 Jon
# 89
# 12 Daenerys
# 138
# 13 Eddard
# 187
# 14 Tyrion
# 138
# 15 Catelyn
# 165
# 16 Sansa
# 265
# 17 Eddard
# 158
# 18 Bran
# 17
# 19 Catelyn
# 167
# 20 Jon
# 219
# 21 Eddard
# 273
# 22 Tyrion
# 178
# 23 Arya
# 185
# 24 Daenerys
# 208
# 25 Bran
# 206
# 26 Eddard
# 148
# 27 Jon
# 247
# 28 Eddard
# 212
# 29 Catelyn
# 149
# 30 Sansa
# 196
# 31 Eddard
# 392
# 32 Tyrion
# 246
# 33 Arya
# 141
# 34 Eddard
# 164
# 35 Catelyn
# 359
# 36 Eddard
# 140
# 37 Daenerys
# 172
# 38 Bran
# 221
# 39 Tyrion
# 225
# 40 Eddard
# 169
# 41 Catelyn
# 249
# 42 Jon
# 133
# 43 Tyrion
# 134
# 44 Eddard
# 186
# 45 Sansa
# 170
# 46 Eddard
# 159
# 47 Daenerys
# 177
# 48 Eddard
# 315
# 49 Jon
# 161
# 50 Eddard
# 150
# 51 Arya
# 154
# 52 Sansa
# 183
# 53 Jon
# 278
# 54 Bran
# 255
# 55 Daenerys
# 187
# 56 Catelyn
# 202
# 57 Tyrion
# 195
# 58 Sansa
# 191
# 59 Eddard
# 165
# 60 Catelyn
# 251
# 61 Jon
# 188
# 62 Daenerys
# 178
# 63 Tyrion
# 283
# 64 Catelyn
# 154
# 65 Daenerys
# 286
# 66 Arya
# 146
# 67 Bran
# 143
# 68 Sansa
# 113
# 69 Daenerys
# 163
# 70 Tyrion
# 196
# 71 Jon
# 190
# 72 Catelyn
# 260
# 73 Daenerys
# 121

# %%
with open('books/GOT1.txt') as fp:
    book = fp.read()
    chapters = book.split('\n\n\n\n\n')
    for i in range(0,len(chapters)):
        name =[word for word in chapters[i].split('\n') if len(word.strip())>0][0]
        print(i+1,name.title())
        chapter = ' '.join([word.replace('\t','').replace('"','') for word in chapters[i].split('\n') if len(word.strip())>0][1:])
        
        doc3 = nlp3(chapter)
        lg = set()
        for ent in doc3.ents:
            if ent.label_ == 'PERSON':
                lg.add((ent.text, ent.start_char, ent.end_char))
        spacy.displacy.render(doc3, style='dep')   
        #print(len(lg))
        break
# Out:
# 1 Prologue
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="de0adbc26d214c1084d83bc1c78106fd-0" class="displacy" width="678525" height="1887.0" direction="ltr" style="max-width: none; height: 1887.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">We</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">should</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">start</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">back,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Gared</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">urged</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">woods</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">began</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">grow</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">dark</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">around</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">them.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">wildlings</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">dead.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">Do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">dead</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">frighten</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">you?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">Ser</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">Waymar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">Royce</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">asked</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">just</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="53

# %%
[i for i in chapter.split('\n') if len(i)>0][0]
# Out:
# 'catelyn Stark'
