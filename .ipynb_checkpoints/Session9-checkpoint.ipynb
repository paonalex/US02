# %% [markdown]
# session 7 analyse AWOIF Characters pages
# To analyze the pages we need to
#
# 1. Read all the html and create a DOM tree with
# 2. Look inside teh DOM tree to find the infobox
# 3. inside the infobox get the various fields that we need including
#     - full name (title of the page)
#     - caption name (title of the infobox)
#     - aliases
#     - books
#     - titles
#     - infobox items count (field of the infobox)
#     - role (how character appears in the book, books field)
#     - role score (score of the character role)
#     - page size (how many characters in the page)
#     - links of the page
#     - if no infobox is found, the character is discarded
#
# The code use a variety of technics to extract, clean and array each field Biggest technical difficulty is the cleaning code:
#
# aliases, title and books in the format 'BranStark (appears)[N 1]' that needs to be transformed into ['Bran', 'Sark']. This is achieved with regular expressions matching certain patterns in the text. An example of the regex used in this example is available on regex101.com
#
# books volume title is converted into a number with the use of a dictionary
#
# As usual we begin by declaring the various helper libraries we might need to achieve the analysis. Typically we will need DOM Tree helper BeautifulSoup, regular expressions re and directory listing os as well as a self define dictionary

# %%
from bs4 import BeautifulSoup
import re
import os

books_number ={'the world of ice & fire':0,'a game of thrones':1,
    'a clash of kings':2,
    'a storm of swords':3,
    'a feast for crows':4,
    'a dance with dragons':5}

role_scoring = {'Appears':0.8,
 'Mentioned':0.5,
 'POV':1,
 'apendix':0.2,
 'appears':0.8,
 'appedix':0.2,
 'appendi':0.2,
 'appendix':0.2,
 'mentioned':0.5,
 'mentions':0.5}

# %% [markdown]
# infobox class
# The class helps packing all the useful extraction in a neat package. Self is a self reference to the class itself, needed to access inside data between functions.

# %%
class Record:
    def __init__(self, html):
        self.name = None
        self.fullname = None
        self.titles = None
        self.aliases = None
        self.books = None
        self.roleInBook = None
        self.roleScore = None
        self.pageSize = None
        self.links = []
        self.infoboxSize = 0
        self.soup = BeautifulSoup(html,'html5lib') #CONTIENT BEAUTIFUL SOUP
    
        self.pageSize = len(self.soup.text) # tout ce qu'on va voir à l'écran de la page html, juste longueur du txt
    
    def informations(self): #
        return {'name':self.name,
                'fullname':self.fullname,
                'titles':self.titles, 
                'aliases':self.aliases,
                'books':self.books, 
                'roleInBooks':self.roleInBook,
                'roleScore':self.roleScore,
                'links':self.links,
                'infoboxSize':self.infoboxSize,
                'pageSize':self.pageSize}
    
    def getLinks(self):
        global names
        cLinks = []
        links = soup.find_all('a')
        for link in links:
            if 'href' in link.attrs.keys():
                name = link['href'].split('/')[-1]
                if name in names:
                    self.links.append(name)

    
    def clean_and_split_list_like_cell(self,llcell, books=False): #self: accéder aux autres variables dans cette class
        # get PARENTHESIS content if it is parenthesis and books
        if books:
            regex = r"\((?P<role>\w+)\)" #recuper ce qu'il y a entre parenthèse ouvrante et fermante et on l'appelle rôle
            matches = re.finditer(regex, llcell, re.MULTILINE)
            roleInBook = [match.group('role') for match in matches]
            if len(roleInBook)>0:
                self.roleScore = sum([role_scoring[rib] for rib in roleInBook])
                self.roleInBook = roleInBook
            
            regex = r"\(\w+\)" # REMOVE PARENTHESIS 
            llcell = re.split(regex,llcell)
            return llcell
            
        else:
            regex = r"\s?\([\w\s]+\)" # REMOVE PARENTHESIS 
            llcell = re.sub(regex,'',llcell, 0, re.MULTILINE)
            
            regex = r"\[[\w\s]+\]" # REMOVE REFERENCES
            llcell = re.sub(regex,'',llcell, 0, re.MULTILINE)

            regex = r"([a-z])([A-Z])" # SPLIT lowerUPPER coupe quand on a minuscule puis majuscule
            subst = "\\1|\\2"
            llcell = re.sub(regex, subst, llcell, 0, re.MULTILINE).split('|')
            llcell = [i.strip() for i in llcell if len(i.strip())>0]
            return llcell
    
    def getBooks(self,value):
        books = self.clean_and_split_list_like_cell(value, books=True)
        books = [books_number[b.strip().lower()] if len(b.strip())>0 and b.strip().lower() in books_number.keys() else 0 for b in books ]
        if len(books) > 0:
            self.books = books
    
    def getName(self):
        try:
            self.name = self.infobox.caption.get_text().strip()
        except AttributeError:
            pass
        
    def getFullName(self, value):
        self.fullname = value
        
    def getAliases(self,value):
        aliases = self.clean_and_split_list_like_cell(value) #on a une cellule qui ressemble à une lsite et on la nettoie et la coupe
        if len(aliases)>0:
            self.aliases = aliases
        
    def getTitles(self,value):
        titles = self.clean_and_split_list_like_cell(value)
        if len(titles)>0:
            self.titles = titles
    
    def analyze_infobox(self):
        try:
            self.infobox = self.soup.find_all("table", class_="infobox")[0]
        except IndexError:
            return
        self.getName()
        try:
            trs = self.infobox.find_all('tr')
        except:
            return 
        
        for tr in trs:
            try:
                key = tr.th.get_text().strip().lower()
                value = tr.td.get_text().strip() #contenu de la case
            except AttributeError:
                continue
                
            if 'full name' in key:
                self.getFullName(value)
                self.infoboxSize += len(self.fullname)
            elif 'alias' in key:
                self.getAliases(value)
                self.infoboxSize += len(self.aliases)
            elif 'title' in key:
                self.getTitles(value)
                self.infoboxSize += len(self.titles)
            elif 'book' in key:
                self.getBooks(value)
                self.infoboxSize += len(self.books)
            else:
                self.infoboxSize += len(self.clean_and_split_list_like_cell(value)) #si c'est autre chose que full name alias title bbok on essaye quand même de couper pour réucper

# %%
records = []
names = []
for file in os.listdir(path = 'awoif/'):
    if file.endswith('.html'):
         with open('awoif/' + file, encoding='utf_8') as fp: #a l'issue du with le fichier est bien fermé
            names.append(file.split('.')[0])
            html = fp.read()
            record = Record(html)
            record.analyze_infobox()
            records.append(record.informations())

# %%
records
# Out:
# [{'name': 'Addam Frey',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [0, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 8374},
#  {'name': 'Addam Marbrand',
#   'fullname': None,
#   'titles': ['Ser', 'Commander of the City Watch'],
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5, 0],
#   'roleInBooks': ['appears', 'appears', 'appears', 'appears', 'appendix'],
#   'pageSize': 19378},
#  {'name': 'Addam Osgrey',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [0, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 9010},
#  {'name': 'Addam Velaryon',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': ['Addam of Hull'],
#   'books': [0, 0, 0, 0],
#   'roleInBooks': ['mentioned', 'mentioned', 'mentioned'],
#   'pageSize': 14856},
#  {'name': 'Addison Hill',
#   'fullname': None,
#   'titles': ['Ser', 'Lord Commander of the Kingsguard'],
#   'aliases': ['Bastard of Cornfield'],
#   'books': [0, 0, 4, 0],
#   'roleInBooks': ['mentioned', 'mentioned', 'mentioned'],
#   'pageSize': 12768},
#  {'name': 'Aegon Blackfyre',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [0, 0, 0, 0],
#   'roleInBooks': ['mentioned', 'mentioned', 'mentioned'],
#   'pageSize': 10509},
#  {'name': 'Aegon Frey',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Aegon Bloodborn'],
#   'books': [2, 3, 4, 5, 0],
#   'roleInBooks': ['mentioned', 'mentioned', 'mentioned', 'mentioned'],
#   'pageSize': 8455},
#  {'name': 'Aegon Frey',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Jinglebell'],
#   'books': [2, 3, 4, 5, 0],
#   'roleInBooks': ['mentioned', 'appears', 'appendix', 'mentioned'],
#   'pageSize': 12998},
#  {'name': 'Aegon III',
#   'fullname': 'Aegon Targaryen the Third of His Name',
#   'titles': ['King of the Andals, the Rhoynar, and the First Men',
#    'Lord of the Seven Kingdoms',
#    'Protector of the Realm'],
#   'aliases': ['Aegon the Younger',
#    'Aegon the Dragonbane',
#    'Aegon the Unlucky',
#    'The Broken King'],
#   'books': [0, 0, 0, 0, 0, 1, 3, 4, 5, 0],
#   'roleInBooks': ['mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned'],
#   'pageSize': 46334},
#  {'name': 'Aegon II',
#   'fullname': 'Aegon Targaryen the Second of His Name',
#   'titles': ['King of the Andals, the Rhoynar, and the First Men',
#    'Lord of the Seven Kingdoms',
#    'Protector of the Realm'],
#   'aliases': ['Aegon the Elder', 'Aegon the Usurper'],
#   'books': [0, 0, 0, 0, 1, 3, 4, 0],
#   'roleInBooks': ['mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned'],
#   'pageSize': 35913},
#  {'name': 'Aegon IV',
#   'fullname': 'Aegon Targaryen the Fourth of His Name',
#   'titles': ['King of the Andals, the Rhoynar, and the First Men',
#    'Lord of the Seven Kingdoms',
#    'Protector of the Realm'],
#   'aliases': ['Aegon the Unworthy'],
#   'books': [0, 0, 0, 0, 1, 2, 3, 4, 5, 0],
#   'roleInBooks': ['mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned'],
#   'pageSize': 35372},
#  {'name': 'Aegon I',
#   'fullname': 'Aegon Targaryen the First of His Name',
#   'titles': ['King of All Westeros',
#    'Shield of His People',
#    'King of the Andals, the Rhoynar, and the First Men',
#    'Lord of the Seven Kingdoms',
#    'Protector of the Realm',
#    'Lord of Dragonstone'],
#   'aliases': ['Aegon the Conqueror',
#    'Aegon the Dragonlord',
#    'Aegon the Dragon'],
#   'books': [0, 0, 0, 0, 0, 0, 1, 2, 3, 4, 5, 0],
#   'roleInBooks': ['mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned'],
#   'pageSize': 27437},
#  {'name': 'Aegon Targaryen',
#   'fullname': None,
#   'titles': ['Prince of Dragonstone'],
#   'aliases': ['The pretender', 'Aegon the Uncrowned'],
#   'books': [0, 0, 0, 0],
#   'roleInBooks': ['mentioned', 'mentioned', 'mentioned'],
#   'pageSize': 15817},
#  {'name': 'Aegon Targaryen',
#   'fullname': None,
#   'titles': ['Prince'],
#   'aliases': None,
#   'books': [0, 0, 0],
#   'roleInBooks': ['mentioned', 'mentioned'],
#   'pageSize': 8459},
#  {'name': 'Aegon Targaryen',
#   'fullname': None,
#   'titles': ['Prince'],
#   'aliases': None,
#   'books': [0, 0, 0],
#   'roleInBooks': ['appendix', 'mentioned'],
#   'pageSize': 9174},
#  {'name': 'Aegon Targaryen',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Young Griff'],
#   'books': [0, 1, 2, 3, 4, 5, 0],
#   'roleInBooks': ['mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'appears'],
#   'pageSize': 40002},
#  {'name': 'Aegon V',
#   'fullname': 'Aegon Targaryen the Fifth of His Name',
#   'titles': ['King of the Andals, the Rhoynar, and the First Men',
#    'Lord of the Seven Kingdoms',
#    'Protector of the Realm'],
#   'aliases': ['Aegon the Unlikely',
#    'Aegon the Fortunate',
#    'Egg',
#    'The Prince Who Was An Egg'],
#   'books': [0, 0, 0, 0, 1, 2, 3, 4, 5, 0],
#   'roleInBooks': ['mentioned',
#    'appears',
#    'appears',
#    'appears',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned'],
#   'pageSize': 24048},
#  {'name': 'Aegor Rivers',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': ['Bittersteel'],
#   'books': [0, 0, 0, 4, 5, 0, 0],
#   'roleInBooks': ['mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned'],
#   'pageSize': 16101},
#  {'name': 'Aelinor Penrose',
#   'fullname': None,
#   'titles': ['Lady', 'Queen'],
#   'aliases': ['Aelinor Targaryen'],
#   'books': [0, 0, 0],
#   'roleInBooks': ['mentioned', 'mentioned'],
#   'pageSize': 11939},
#  {'name': 'Aemma Arryn',
#   'fullname': None,
#   'titles': ['Lady', 'Queen'],
#   'aliases': None,
#   'books': [0, 0, 0, 0, 0],
#   'roleInBooks': ['mentioned', 'mentioned', 'mentioned', 'mentioned'],
#   'pageSize': 12296},
#  {'name': 'Aemond Targaryen',
#   'fullname': None,
#   'titles': ['Prince', 'Protector of the Realm', 'Prince Regent'],
#   'aliases': ['Aemond One-Eye', 'Aemond the Kinslayer'],
#   'books': [0, 0, 0, 0, 5, 0],
#   'roleInBooks': ['mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned'],
#   'pageSize': 20175},
#  {'name': 'Aemon Blackfyre',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [0, 0, 0, 3, 0],
#   'roleInBooks': ['mentioned', 'mentioned', 'mentioned', 'mentioned'],
#   'pageSize': 10532},
#  {'name': 'Aemon Costayne',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [3, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7739},
#  {'name': 'Aemon Estermont',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [2, 3, 4, 5, 0],
#   'roleInBooks': ['appendix', 'appendix', 'appendix', 'appendix'],
#   'pageSize': 8820},
#  {'name': 'Aemon Rivers',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [2, 3, 4, 0],
#   'roleInBooks': ['appendix', 'mentioned', 'appendix'],
#   'pageSize': 8643},
#  {'name': 'Aemon',
#   'fullname': None,
#   'titles': ['Prince', 'Maester at Dragonstone', 'Maester at Castle Black'],
#   'aliases': ['Aemon Targaryen', 'Uncle Maester'],
#   'books': [0, 0, 0, 0, 1, 2, 3, 4, 5, 0],
#   'roleInBooks': ['mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'appears',
#    'mentioned',
#    'appears',
#    'appears',
#    'appears'],
#   'pageSize': 21239},
#  {'name': 'Aemon Targaryen',
#   'fullname': None,
#   'titles': ['Prince', 'Ser', 'Lord Commander of the Kingsguard'],
#   'aliases': ['The Dragonknight', 'The Knight of Tears'],
#   'books': [0, 0, 0, 0, 1, 2, 3, 4, 5, 0],
#   'roleInBooks': ['mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned'],
#   'pageSize': 24918},
#  {'name': 'Aenys Frey',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5, 0, 0],
#   'roleInBooks': ['appears',
#    'appears',
#    'appears',
#    'mentioned',
#    'appears',
#    'mentioned'],
#   'pageSize': 14880},
#  {'name': 'Aenys I',
#   'fullname': 'Aenys Targaryen the First of His Name',
#   'titles': ['King of the Andals, the Rhoynar, and the First Men',
#    'Lord of the Seven Kingdoms',
#    'Protector of the Realm'],
#   'aliases': ['King Abomination'],
#   'books': [0, 0, 0, 1, 0],
#   'roleInBooks': ['mentioned', 'mentioned', 'mentioned', 'appendix'],
#   'pageSize': 25070},
#  {'name': 'Aerion Targaryen',
#   'fullname': None,
#   'titles': ['Prince'],
#   'aliases': ['Aerion Brightflame',
#    'Aerion Brightfire',
#    'Aerion the Monstrous',
#    'The Bright Prince',
#    'The Prince Who Thought He Was a Dragon'],
#   'books': [0, 0, 0, 0, 2, 3, 5, 0],
#   'roleInBooks': ['mentioned',
#    'appears',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned'],
#   'pageSize': 14999},
#  {'name': 'Aeron Greyjoy',
#   'fullname': None,
#   'titles': ['Priest of the Drowned God', 'Captain of the Golden Storm'],
#   'aliases': ['The Damphair', 'Aeron Damphair'],
#   'books': [1, 2, 3, 4, 5, 0, 0],
#   'roleInBooks': ['mentioned',
#    'appears',
#    'mentioned',
#    'POV',
#    'mentioned',
#    'POV'],
#   'pageSize': 22900},
#  {'name': 'Aerys II',
#   'fullname': 'Aerys Targaryen the Second of His Name',
#   'titles': ['King of the Andals, the Rhoynar, and the First Men',
#    'Lord of the Seven Kingdoms',
#    'Protector of the Realm',
#    'Ser'],
#   'aliases': ['The Mad King', 'King Scab'],
#   'books': [0, 1, 2, 3, 4, 5, 0, 0],
#   'roleInBooks': ['mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned'],
#   'pageSize': 49289},
#  {'name': 'Aerys I',
#   'fullname': 'Aerys Targaryen the First of His Name',
#   'titles': ['King of the Andals, the Rhoynar, and the First Men',
#    'Lord of the Seven Kingdoms',
#    'Protector of the Realm'],
#   'aliases': None,
#   'books': [0, 0, 0, 0, 1, 2, 5, 0],
#   'roleInBooks': ['mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'appendix',
#    'mentioned',
#    'mentioned'],
#   'pageSize': 15775},
#  {'name': 'Aethan',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [3, 0],
#   'roleInBooks': ['mentions'],
#   'pageSize': 7903},
#  {'name': 'Aethelmure',
#   'fullname': None,
#   'titles': ['Grand Maester'],
#   'aliases': None,
#   'books': [1, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 8419},
#  {'name': 'Aggar',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [2, 5, 0],
#   'roleInBooks': ['appears', 'mentioned'],
#   'pageSize': 8936},
#  {'name': 'Aggo',
#   'fullname': None,
#   'titles': ['Ko\n\nBloodrider of Daenerys Targaryen'],
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5, 0],
#   'roleInBooks': ['appears', 'appears', 'appears', 'mentioned', 'appears'],
#   'pageSize': 13458},
#  {'name': 'Aglantine',
#   'fullname': None,
#   'titles': ['Septa'],
#   'aliases': None,
#   'books': [4, 5, 0],
#   'roleInBooks': ['mentioned', 'appendix'],
#   'pageSize': 7893},
#  {'name': 'Agrivane',
#   'fullname': None,
#   'titles': ['Archmaester'],
#   'aliases': None,
#   'books': [4, 0],
#   'roleInBooks': ['appendix'],
#   'pageSize': 7450},
#  {'name': 'Aladale Wynch',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [2, 3, 0],
#   'roleInBooks': ['appendix', 'mentioned'],
#   'pageSize': 8037},
#  {'name': 'Alan of Rosby',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [3, 4, 5, 0],
#   'roleInBooks': ['appears', 'appendix', 'appendix'],
#   'pageSize': 8976},
#  {'name': 'Alannys Harlaw',
#   'fullname': None,
#   'titles': ['Lady of Pyke', 'Queen of the Iron Islands'],
#   'aliases': ['Lanny'],
#   'books': [1, 2, 4, 5, 0],
#   'roleInBooks': ['appendix', 'mentioned', 'mentioned', 'mentioned'],
#   'pageSize': 13289},
#  {'name': 'Alaric of Eysen',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [3, 4, 0],
#   'roleInBooks': ['mentioned', 'mentioned'],
#   'pageSize': 8606},
#  {'name': 'Alayaya',
#   'fullname': None,
#   'titles': None,
#   'aliases': ["'Yaya"],
#   'books': [2, 3, 4, 5, 0],
#   'roleInBooks': ['appears', 'mentioned', 'mentioned', 'appendix'],
#   'pageSize': 10135},
#  {'name': 'Albar Royce',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5, 0, 0],
#   'roleInBooks': ['appears',
#    'mentioned',
#    'appendix',
#    'appears',
#    'appendix',
#    'appears'],
#   'pageSize': 8993},
#  {'name': 'Albett',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Pimple'],
#   'books': [1, 2, 3, 4, 5, 0],
#   'roleInBooks': ['appears', 'appendix', 'appendix', 'appendix', 'appendix'],
#   'pageSize': 8460},
#  {'name': 'Alebelly',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [2, 3, 0],
#   'roleInBooks': ['appears', 'mentioned'],
#   'pageSize': 8295},
#  {'name': 'Alekyne Florent',
#   'fullname': None,
#   'titles': ['Lord of Brightwater'],
#   'aliases': None,
#   'books': [2, 3, 4, 0],
#   'roleInBooks': ['appendix', 'mentioned', 'appendix'],
#   'pageSize': 9651},
#  {'name': 'Alequo Adarys',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Silvertongue', 'The Tyrant of Tyrosh'],
#   'books': [0, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 8629},
#  {'name': 'Alerie Hightower',
#   'fullname': None,
#   'titles': ['Lady of Highgarden'],
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5, 0],
#   'roleInBooks': ['appendix', 'appendix', 'appears', 'appears', 'appendix'],
#   'pageSize': 10196},
#  {'name': 'Alesander Frey',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [2, 3, 4, 0],
#   'roleInBooks': ['appendix', 'mentioned', 'appendix'],
#   'pageSize': 9427},
#  {'name': 'Alesander Staedmon',
#   'fullname': None,
#   'titles': ['Lord of Broad Arch'],
#   'aliases': ['the Pennylover'],
#   'books': [2, 3, 4, 0],
#   'roleInBooks': ['appears', 'appendix', 'appendix'],
#   'pageSize': 8659},
#  {'name': 'Alesandor Torrent',
#   'fullname': None,
#   'titles': ['Lord of Littlesister'],
#   'aliases': None,
#   'books': [4, 5, 0],
#   'roleInBooks': ['appendix', 'mentioned'],
#   'pageSize': 8007},
#  {'name': 'Alester Florent',
#   'fullname': None,
#   'titles': ['Lord of Brightwater Keep', 'Hand of the King'],
#   'aliases': None,
#   'books': [2, 3, 4, 5, 0],
#   'roleInBooks': ['appears', 'appears', 'appendix', 'mentioned'],
#   'pageSize': 18010},
#  {'name': 'Alester Norcross',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [2, 3, 4, 0],
#   'roleInBooks': ['appendix', 'appendix', 'appendix'],
#   'pageSize': 8042},
#  {'name': 'Alester Oakheart',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [4, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 8234},
#  {'name': 'Alfyn',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Alfyn Crowkiller'],
#   'books': [2, 3, 4, 5, 0],
#   'roleInBooks': ['mentioned', 'mentioned', 'appendix', 'mentioned'],
#   'pageSize': 9092},
#  {'name': 'Alia of Braavos',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [1, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7576},
#  {'name': 'Alicent Hightower',
#   'fullname': None,
#   'titles': ['Lady', 'Queen', 'Dowager Queen'],
#   'aliases': ['The Queen in Chains'],
#   'books': [0, 0, 0, 0, 0],
#   'roleInBooks': ['mentioned', 'mentioned', 'mentioned', 'mentioned'],
#   'pageSize': 22356},
#  {'name': 'All-for-Joffrey',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [2, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 9089},
#  {'name': 'Allaquo',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [4, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7538},
#  {'name': 'Allard Seaworth',
#   'fullname': None,
#   'titles': ['Captain of the Lady Marya'],
#   'aliases': None,
#   'books': [2, 3, 4, 5, 0],
#   'roleInBooks': ['appears', 'mentioned', 'appendix', 'mentioned'],
#   'pageSize': 9208},
#  {'name': 'Allar Deem',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [2, 3, 0],
#   'roleInBooks': ['mentioned', 'mentioned'],
#   'pageSize': 9097},
#  {'name': 'Alla Tyrell',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [3, 4, 5, 0],
#   'roleInBooks': ['appears', 'appears', 'mentioned'],
#   'pageSize': 10487},
#  {'name': 'Alliser Thorne',
#   'fullname': None,
#   'titles': ['Ser', 'Master-at-arms at Castle Black'],
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5, 0],
#   'roleInBooks': ['appears', 'appears', 'appears', 'mentioned', 'appears'],
#   'pageSize': 14932},
#  {'name': 'Allyria Dayne',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [3, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 8595},
#  {'name': 'Alvyn Sharp',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [4, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 8242},
#  {'name': 'Alyce',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [3, 4, 0],
#   'roleInBooks': ['mentioned', 'appendix'],
#   'pageSize': 7515},
#  {'name': 'Alyce Graceford',
#   'fullname': None,
#   'titles': ['Lady of Holyhall'],
#   'aliases': None,
#   'books': [3, 4, 5, 0],
#   'roleInBooks': ['appears', 'appears', 'appendix'],
#   'pageSize': 8391},
#  {'name': 'Alyn',
#   'fullname': None,
#   'titles': ['Captain of the guard'],
#   'aliases': None,
#   'books': [1, 2, 3, 5, 0],
#   'roleInBooks': ['appears', 'mentioned', 'mentioned', 'mentioned'],
#   'pageSize': 13610},
#  {'name': 'Alyn Ambrose',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [3, 4, 5, 0],
#   'roleInBooks': ['appears', 'appears', 'appendix'],
#   'pageSize': 9132},
#  {'name': 'Alyn Cockshaw',
#   'fullname': None,
#   'titles': ['Ser', 'Lord'],
#   'aliases': None,
#   'books': [0, 0, 0],
#   'roleInBooks': ['mentioned', 'appears'],
#   'pageSize': 10035},
#  {'name': 'Alyn Connington',
#   'fullname': None,
#   'titles': ['Ser', 'Lord Commander of the Kingsguard'],
#   'aliases': ['The Pale Griffin'],
#   'books': [3, 4, 0],
#   'roleInBooks': ['mentioned', 'mentioned'],
#   'pageSize': 11781},
#  {'name': 'Alyn Estermont',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [2, 3, 4, 5, 0],
#   'roleInBooks': ['appendix', 'appendix', 'appendix', 'appendix'],
#   'pageSize': 8832},
#  {'name': 'Alyn Frey',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [2, 3, 4, 0],
#   'roleInBooks': ['appendix', 'appendix', 'appendix'],
#   'pageSize': 8833},
#  {'name': 'Alyn Haigh',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [2, 3, 4, 0],
#   'roleInBooks': ['appendix', 'appendix', 'appendix'],
#   'pageSize': 8045},
#  {'name': 'Alyn Hunt',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [4, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7937},
#  {'name': 'Alyn Stackspear',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [2, 3, 4, 5, 0],
#   'roleInBooks': ['mentioned', 'appendix', 'appears', 'appendix'],
#   'pageSize': 8695},
#  {'name': 'Alyn Velaryon',
#   'fullname': None,
#   'titles': ['Ser',
#    'Lord of the Tides',
#    'Master of Driftmark',
#    'Admiral',
#    'Master of ships',
#    'Captain of Queen Rhaenys',
#    'Captain of Lady Baela',
#    'Captain of Bold Marilda'],
#   'aliases': ['Alyn of Hull',
#    'Oakenfist',
#    'Alyn Oakenfist',
#    'Lord Oakenfist',
#    'Hero of the Stepstones'],
#   'books': [0, 0, 0, 4, 5, 0],
#   'roleInBooks': ['mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned'],
#   'pageSize': 25890},
#  {'name': 'Alysane Mormont',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['She-Bear', 'Aly'],
#   'books': [4, 5, 0, 0],
#   'roleInBooks': ['appendix', 'appears', 'mentioned'],
#   'pageSize': 12501},
#  {'name': 'Alysanne Bracken',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [5, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 8046},
#  {'name': 'Alysanne Bulwer',
#   'fullname': None,
#   'titles': ['Lady of Blackcrown'],
#   'aliases': None,
#   'books': [3, 4, 5, 0],
#   'roleInBooks': ['mentioned', 'mentioned', 'appendix'],
#   'pageSize': 8700},
#  {'name': 'Alysanne Hightower',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [4, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 8772},
#  {'name': 'Alysanne Lefford',
#   'fullname': None,
#   'titles': ['Lady of the Golden Tooth'],
#   'aliases': None,
#   'books': [4, 5, 0],
#   'roleInBooks': ['appendix', 'appendix'],
#   'pageSize': 7920},
#  {'name': 'Alysanne Tarth',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [4, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 8092},
#  {'name': 'Alysanne Osgrey',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [0, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 8543},
#  {'name': 'Alysanne Targaryen',
#   'fullname': None,
#   'titles': ['Princess', 'Queen'],
#   'aliases': ['Good Queen Alysanne', 'The little maid', 'The other daughter'],
#   'books': [0, 0, 0, 0, 0, 3, 4, 5, 0, 0],
#   'roleInBooks': ['mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned'],
#   'pageSize': 43571},
#  {'name': 'Alyssa Arryn',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [0, 1, 0],
#   'roleInBooks': ['mentioned', 'mentioned'],
#   'pageSize': 9506},
#  {'name': 'Alyssa Blackwood',
#   'fullname': None,
#   'titles': ['Lady of the Crossing'],
#   'aliases': None,
#   'books': [2, 3, 4, 5, 0],
#   'roleInBooks': ['appendix', 'appendix', 'appendix', 'mentioned'],
#   'pageSize': 9359},
#  {'name': 'Alys Arryn',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [4, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 9225},
#  {'name': 'Alys Frey',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [2, 3, 4, 0],
#   'roleInBooks': ['appendix', 'appendix', 'appendix'],
#   'pageSize': 8258},
#  {'name': 'Alys Karstark',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [3, 4, 5, 0],
#   'roleInBooks': ['mentioned', 'appendix', 'appears'],
#   'pageSize': 13800},
#  {'name': 'Alyx Frey',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [2, 3, 4, 0],
#   'roleInBooks': ['appendix', 'appears', 'appendix'],
#   'pageSize': 9400},
#  {'name': 'Amabel',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [2, 3, 0],
#   'roleInBooks': ['appears', 'appears'],
#   'pageSize': 10512},
#  {'name': 'Amarei Crakehall',
#   'fullname': None,
#   'titles': ['Lady of the Crossing'],
#   'aliases': None,
#   'books': [0, 2, 3, 4, 5, 0],
#   'roleInBooks': ['mentioned',
#    'mentioned',
#    'mentioned',
#    'appendix',
#    'appendix'],
#   'pageSize': 9460},
#  {'name': 'Ambrode',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [2, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7592},
#  {'name': 'Ambrose Butterwell',
#   'fullname': None,
#   'titles': ['Lord of Whitewalls', 'Master of coin', 'Hand of the King'],
#   'aliases': ['Old Milkblood', 'The lord of cows', 'Lord Butterbutt'],
#   'books': [0, 0, 0, 3, 0],
#   'roleInBooks': ['mentioned', 'mentioned', 'appears', 'mentioned'],
#   'pageSize': 15650},
#  {'name': 'Amerei Frey',
#   'fullname': None,
#   'titles': ['Lady of Darry'],
#   'aliases': ['Gatehouse Ami'],
#   'books': [2, 3, 4, 0],
#   'roleInBooks': ['appendix', 'appears', 'appears'],
#   'pageSize': 12652},
#  {'name': 'Amory Lorch',
#   'fullname': None,
#   'titles': ['Ser', 'Castellan of Harrenhal'],
#   'aliases': ['The Manticore'],
#   'books': [1, 2, 3, 4, 5, 0],
#   'roleInBooks': ['mentioned',
#    'appears',
#    'mentioned',
#    'mentioned',
#    'mentioned'],
#   'pageSize': 12800},
#  {'name': 'Andar Royce',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5, 0],
#   'roleInBooks': ['appears', 'mentioned', 'appendix', 'appendix', 'appendix'],
#   'pageSize': 8529},
#  {'name': 'Anders Yronwood',
#   'fullname': None,
#   'titles': ['Lord of Yronwood', 'The Bloodroyal', 'Warden of the Stone Way'],
#   'aliases': None,
#   'books': [3, 4, 5, 0, 0],
#   'roleInBooks': ['appendix', 'mentioned', 'mentioned', 'mentioned'],
#   'pageSize': 9302},
#  {'name': 'Andrew Estermont',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [2, 3, 4, 5, 0],
#   'roleInBooks': ['appendix', 'appears', 'appendix', 'appendix'],
#   'pageSize': 9204},
#  {'name': 'Andrey Charlton',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [3, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7930},
#  {'name': 'Andrey Dalt',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': ['Drey'],
#   'books': [4, 5, 0, 0],
#   'roleInBooks': ['appears', 'appendix', 'mentioned'],
#   'pageSize': 8747},
#  {'name': 'Andrik',
#   'fullname': None,
#   'titles': ['Lord of Southshield'],
#   'aliases': ['Andrik the Unsmiling'],
#   'books': [2, 3, 4, 5, 0],
#   'roleInBooks': ['mentioned', 'appendix', 'appears', 'appendix'],
#   'pageSize': 9407},
#  {'name': 'Andros Brax',
#   'fullname': None,
#   'titles': ['Lord of Hornvale'],
#   'aliases': None,
#   'books': [1, 2, 3, 0],
#   'roleInBooks': ['mentioned', 'mentioned', 'appendix'],
#   'pageSize': 9389},
#  {'name': 'Androw Ashford',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [0, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 7900},
#  {'name': 'Androw Frey',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [2, 3, 4, 0],
#   'roleInBooks': ['appendix', 'appendix', 'appendix'],
#   'pageSize': 8867},
#  {'name': 'Anguy',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Anguy the Archer', 'Archer'],
#   'books': [1, 3, 4, 0],
#   'roleInBooks': ['appears', 'appears', 'mentioned'],
#   'pageSize': 10017},
#  {'name': 'Annara Farring',
#   'fullname': None,
#   'titles': ['Lady of the Crossing'],
#   'aliases': None,
#   'books': [2, 3, 4, 5, 0],
#   'roleInBooks': ['appendix', 'mentioned', 'appendix', 'appendix'],
#   'pageSize': 8455},
#  {'name': 'Antario Jast',
#   'fullname': None,
#   'titles': ['Lord'],
#   'aliases': None,
#   'books': [2, 3, 4, 5, 0],
#   'roleInBooks': ['mentioned', 'appendix', 'appears', 'appendix'],
#   'pageSize': 8868},
#  {'name': 'Ryn',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Anvyl Ryn'],
#   'books': [3, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7514},
#  {'name': 'Anya Waynwood',
#   'fullname': None,
#   'titles': ['Lady of Ironoaks'],
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5, 0, 0],
#   'roleInBooks': ['appears',
#    'appendix',
#    'appendix',
#    'appears',
#    'appendix',
#    'appears'],
#   'pageSize': 10880},
#  {'name': 'Archibald Yronwood',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': ['the big man', 'Arch', 'Greenguts'],
#   'books': [4, 5, 0],
#   'roleInBooks': ['mentioned', 'appears'],
#   'pageSize': 14323},
#  {'name': 'Ardrian Celtigar',
#   'fullname': None,
#   'titles': ['Lord of Claw Isle'],
#   'aliases': ['The Red Crab'],
#   'books': [2, 3, 0],
#   'roleInBooks': ['appears', 'appears'],
#   'pageSize': 9425},
#  {'name': 'Areo Hotah',
#   'fullname': None,
#   'titles': ['Captain of guards at Sunspear'],
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5, 0, 0],
#   'roleInBooks': ['mentioned', 'mentioned', 'mentioned', 'POV', 'POV', 'POV'],
#   'pageSize': 12288},
#  {'name': 'Argilac Durrandon',
#   'fullname': None,
#   'titles': ['Storm King'],
#   'aliases': ['Argilac the Arrogant'],
#   'books': [0, 1, 5, 0],
#   'roleInBooks': ['mentioned', 'appendix', 'mentioned'],
#   'pageSize': 11479},
#  {'name': 'Argrave the Defiant',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [0, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 7819},
#  {'name': 'Arianne Martell',
#   'fullname': None,
#   'titles': ['Princess'],
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5, 0, 0],
#   'roleInBooks': ['mentioned',
#    'mentioned',
#    'mentioned',
#    'POV',
#    'appears',
#    'POV'],
#   'pageSize': 30149},
#  {'name': 'Arianne Tarth',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [4, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 8081},
#  {'name': 'Arlan of Pennytree',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [0, 0, 0, 0],
#   'roleInBooks': ['mentioned', 'mentioned', 'mentioned'],
#   'pageSize': 10711},
#  {'name': 'Armen',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Armen the Acolyte'],
#   'books': [4, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 7856},
#  {'name': 'Armond Caswell',
#   'fullname': None,
#   'titles': ['Lord of Bitterbridge'],
#   'aliases': None,
#   'books': [0, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7919},
#  {'name': 'Arneld',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [2, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7596},
#  {'name': 'Arnell',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [2, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7791},
#  {'name': 'Arnolf Karstark',
#   'fullname': None,
#   'titles': ['Castellan of Karhold'],
#   'aliases': ['Lord Arnolf'],
#   'books': [4, 5, 0, 0],
#   'roleInBooks': ['appendix', 'appears', 'appears'],
#   'pageSize': 14286},
#  {'name': 'Aron Santagar',
#   'fullname': None,
#   'titles': ['Ser', 'Master-at-arms at the Red Keep'],
#   'aliases': None,
#   'books': [1, 2, 4, 0],
#   'roleInBooks': ['appears', 'appears', 'mentioned'],
#   'pageSize': 9431},
#  {'name': 'Arrec Durrandon',
#   'fullname': 'Arrec Durrandon',
#   'titles': ['Storm King'],
#   'aliases': None,
#   'books': [0, 1, 0],
#   'roleInBooks': ['mentioned', 'appendix'],
#   'pageSize': 9299},
#  {'name': 'Arron',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [3, 4, 5, 0],
#   'roleInBooks': ['appears', 'appendix', 'appears'],
#   'pageSize': 8487},
#  {'name': 'Arron Qorgyle',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [3, 4, 0],
#   'roleInBooks': ['appears', 'appendix'],
#   'pageSize': 8299},
#  {'name': 'Arryk',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['"Left" or "Right"'],
#   'books': [3, 4, 0],
#   'roleInBooks': ['appears', 'appears'],
#   'pageSize': 8074},
#  {'name': 'Arryk Cargyll',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [0, 0, 0, 0, 1, 2, 4, 0],
#   'roleInBooks': ['mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned'],
#   'pageSize': 10642},
#  {'name': 'Arson',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Arson Iceaxe'],
#   'books': [3, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 8138},
#  {'name': 'Arthor Karstark',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [5, 0, 0],
#   'roleInBooks': ['appears', 'appears'],
#   'pageSize': 9820},
#  {'name': 'Arthur Ambrose',
#   'fullname': None,
#   'titles': ['Lord'],
#   'aliases': None,
#   'books': [3, 4, 5, 0],
#   'roleInBooks': ['mentioned', 'appendix', 'appendix'],
#   'pageSize': 8318},
#  {'name': 'Arthur Dayne',
#   'fullname': None,
#   'titles': ['Ser', 'Sword of the Morning'],
#   'aliases': None,
#   'books': [0, 1, 2, 3, 4, 5, 0],
#   'roleInBooks': ['mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned'],
#   'pageSize': 15634},
#  {'name': 'Artos Stark',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Artos the Implacable'],
#   'books': [0, 2, 5, 0],
#   'roleInBooks': ['mentioned', 'mentioned', 'mentioned'],
#   'pageSize': 9728},
#  {'name': 'Artys I Arryn',
#   'fullname': 'Artys Arryn, the First of His Name',
#   'titles': ['King of Mountain and Vale', 'Ser'],
#   'aliases': ['Falcon Knight', 'Winged Knight'],
#   'books': [0, 4, 0],
#   'roleInBooks': ['mentioned', 'mentioned'],
#   'pageSize': 10866},
#  {'name': 'Arwood Frey',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [2, 3, 4, 0],
#   'roleInBooks': ['appendix', 'appendix', 'appears'],
#   'pageSize': 9849},
#  {'name': 'Arwyn Frey',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [2, 3, 4, 5, 0],
#   'roleInBooks': ['appendix', 'appears', 'appendix', 'appendix'],
#   'pageSize': 8498},
#  {'name': 'Arwyn Oakheart',
#   'fullname': None,
#   'titles': ['Lady of Old Oak'],
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5, 0],
#   'roleInBooks': ['appendix', 'appears', 'mentioned', 'appendix', 'appendix'],
#   'pageSize': 9255},
#  {'name': 'Arya Stark',
#   'fullname': None,
#   'titles': ['Princess'],
#   'aliases': ['Arya Horseface',
#    'Arya Underfoot',
#    'Arry',
#    'Lumpyhead',
#    'Lumpyface',
#    'Stickboy',
#    'Rabbitkiller',
#    'Weasel',
#    'Nymeria',
#    'Nan',
#    'Squab',
#    'Wolf girl',
#    'Salty',
#    'Cat of the Canals',
#    'Blind Beth',
#    'The blind girl',
#    'The ugly girl',
#    'Mercedene',
#    'Mercy'],
#   'books': [0, 1, 2, 3, 4, 5, 0, 0],
#   'roleInBooks': ['appendix', 'POV', 'POV', 'POV', 'POV', 'POV', 'POV'],
#   'pageSize': 41405},
#  {'name': 'Arys Oakheart',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': ['The white knight'],
#   'books': [1, 2, 3, 4, 5, 0, 0],
#   'roleInBooks': ['appears',
#    'appears',
#    'mentioned',
#    'POV',
#    'mentioned',
#    'mentioned'],
#   'pageSize': 14719},
#  {'name': 'Ashara Dayne',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [1, 2, 3, 5, 0],
#   'roleInBooks': ['mentioned', 'mentioned', 'mentioned', 'mentioned'],
#   'pageSize': 13089},
#  {'name': 'Asha Greyjoy',
#   'fullname': None,
#   'titles': ['Princess', 'Captain of the Black Wind'],
#   'aliases': ['Esgred', "The kraken's daughter"],
#   'books': [1, 2, 3, 4, 5, 0, 0],
#   'roleInBooks': ['appendix', 'appears', 'mentioned', 'POV', 'POV', 'appears'],
#   'pageSize': 24109},
#  {'name': 'Assadora',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Assadora of Ibben'],
#   'books': [4, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7822},
#  {'name': 'Aubrey Ambrose',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [0, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7796},
#  {'name': 'Aurane Waters',
#   'fullname': None,
#   'titles': ['Grand admiral', 'Lord', 'Lord of the Waters'],
#   'aliases': ['Bastard of Driftmark'],
#   'books': [2, 3, 4, 5, 0],
#   'roleInBooks': ['appears', 'appendix', 'appears', 'mentioned'],
#   'pageSize': 15741},
#  {'name': 'Axell Florent',
#   'fullname': None,
#   'titles': ['Ser', 'Castellan of Dragonstone', "Queen's Hand (self-styled)"],
#   'aliases': None,
#   'books': [2, 3, 4, 5, 0],
#   'roleInBooks': ['appears', 'appears', 'appendix', 'appears'],
#   'pageSize': 16966},
#  {'name': 'Ayrmidon',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [1, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7502},
#  {'name': 'Azor Ahai',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Warrior of Light',
#    'Son of Fire',
#    'Warrior of Fire',
#    'Hyrkoon the Hero',
#    'Yin Tar',
#    'Neferion',
#    'Eldric Shadowchaser'],
#   'books': [0, 2, 3, 4, 5, 0],
#   'roleInBooks': ['mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned'],
#   'pageSize': 12468},
#  {'name': 'Azzak zo Ghazeen',
#   'fullname': None,
#   'titles': ['Cupbearer'],
#   'aliases': None,
#   'books': [5, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 9412},
#  {'name': 'Baela Targaryen',
#   'fullname': None,
#   'titles': ['Lady', 'Princess', 'Lady of Driftmark'],
#   'aliases': ['Baela Velaryon'],
#   'books': [0, 0, 0, 0, 0, 0],
#   'roleInBooks': ['mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned'],
#   'pageSize': 21921},
#  {'name': 'Baelon Targaryen',
#   'fullname': None,
#   'titles': ['Lord of Dragonstone'],
#   'aliases': None,
#   'books': [0, 0, 0],
#   'roleInBooks': ['mentioned', 'mentioned'],
#   'pageSize': 9038},
#  {'name': 'Baelon Targaryen',
#   'fullname': None,
#   'titles': ['Prince'],
#   'aliases': ['Heir for a Day'],
#   'books': [0, 0, 0, 0],
#   'roleInBooks': ['mentioned', 'mentioned', 'mentioned'],
#   'pageSize': 8646},
#  {'name': 'Baelor Blacktyde',
#   'fullname': None,
#   'titles': ['Lord of Blacktyde', 'Captain of the Nightflyer'],
#   'aliases': None,
#   'books': [2, 3, 4, 0],
#   'roleInBooks': ['appendix', 'appendix', 'appears'],
#   'pageSize': 10057},
#  {'name': 'Baelor Hightower',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': ['Baelor Brightsmile', 'Baelor Breakwind'],
#   'books': [3, 4, 0],
#   'roleInBooks': ['mentioned', 'mentioned'],
#   'pageSize': 9707},
#  {'name': 'Baelor I',
#   'fullname': 'Baelor Targaryen the First of His Name',
#   'titles': ['King of the Andals, the Rhoynar, and the First Men',
#    'Lord of the Seven Kingdoms',
#    'Protector of the Realm',
#    'Septon'],
#   'aliases': ['Baelor the Beloved',
#    'Baelor the Blessed',
#    'Baelor the Befuddled'],
#   'books': [0, 0, 1, 2, 3, 4, 5, 0],
#   'roleInBooks': ['mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned'],
#   'pageSize': 21864},
#  {'name': 'Baelor Targaryen',
#   'fullname': None,
#   'titles': ['Prince of Dragonstone',
#    'Protector of the Realm',
#    'Hand of the King'],
#   'aliases': ['Baelor Breakspear', 'The Hammer'],
#   'books': [0, 0, 0, 0, 3, 0, 0],
#   'roleInBooks': ['mentioned',
#    'appears',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned'],
#   'pageSize': 18777},
#  {'name': 'Bael',
#   'fullname': None,
#   'titles': ['King-Beyond-the-Wall'],
#   'aliases': ['Bael the Bard', 'Sygerrik of Skagos'],
#   'books': [0, 2, 3, 0],
#   'roleInBooks': ['mentioned', 'mentioned', 'mentioned'],
#   'pageSize': 12946},
#  {'name': 'Ballabar',
#   'fullname': None,
#   'titles': ['Maester at the Arbor'],
#   'aliases': None,
#   'books': [2, 3, 4, 5, 0],
#   'roleInBooks': ['appears', 'appears', 'mentioned', 'appendix'],
#   'pageSize': 9190},
#  {'name': 'Balman Byrch',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [3, 4, 5, 0],
#   'roleInBooks': ['appendix', 'mentioned', 'appendix'],
#   'pageSize': 9390},
#  {'name': 'Balon Botley',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [4, 0],
#   'roleInBooks': ['appendix'],
#   'pageSize': 8398},
#  {'name': 'Balon IX Greyjoy',
#   'fullname': 'Balon Greyjoy, the Ninth of His Name Since the Grey King',
#   'titles': ['Lord of the Iron Islands',
#    'King of the Iron Islands',
#    'King of the Isles and the North',
#    'King of Salt and Rock',
#    'Son of the Sea Wind',
#    'Lord Reaper of Pyke',
#    'The Greyjoy',
#    'Captain of the Great Kraken'],
#   'aliases': ['Balon the Brave',
#    'Balon the Blessed',
#    'Balon the Twice Crowned',
#    'Balon the Widowmaker',
#    'The wet king',
#    'The kraken king',
#    'The iron king'],
#   'books': [0, 1, 2, 3, 4, 5, 0, 0],
#   'roleInBooks': ['mentioned',
#    'mentioned',
#    'appears',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned'],
#   'pageSize': 23530},
#  {'name': 'Balon Swann',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5, 0],
#   'roleInBooks': ['appears', 'appears', 'appears', 'appears', 'appears'],
#   'pageSize': 20010},
#  {'name': 'Bandy',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [2, 4, 0],
#   'roleInBooks': ['mentioned', 'appendix'],
#   'pageSize': 7872},
#  {'name': 'Bannen',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [3, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 9204},
#  {'name': 'Barbara Bracken',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [5, 0],
#   'roleInBooks': ['appendix'],
#   'pageSize': 8030},
#  {'name': 'Barba Bracken',
#   'fullname': None,
#   'titles': ['Lady'],
#   'aliases': None,
#   'books': [0, 5, 0],
#   'roleInBooks': ['mentioned', 'mentioned'],
#   'pageSize': 11297},
#  {'name': 'Barbrey Dustin',
#   'fullname': None,
#   'titles': ['Lady of Barrowton'],
#   'aliases': None,
#   'books': [4, 5, 0],
#   'roleInBooks': ['appendix', 'appears'],
#   'pageSize': 17251},
#  {'name': 'Barra',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [1, 2, 5, 0],
#   'roleInBooks': ['appears', 'mentioned', 'appendix'],
#   'pageSize': 10735},
#  {'name': 'Barre',
#   'fullname': None,
#   'titles': ['Septon'],
#   'aliases': None,
#   'books': [2, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7939},
#  {'name': 'Barristan Selmy',
#   'fullname': None,
#   'titles': ['Ser', 'Lord Commander of the Kingsguard', 'Hand of the Queen'],
#   'aliases': ['Barristan the Bold',
#    'Barristan the Old',
#    'Arstan Whitebeard',
#    'Ser Grandfather',
#    'Old Ser',
#    'Lord Hand'],
#   'books': [0, 1, 2, 3, 4, 5, 0, 0],
#   'roleInBooks': ['mentioned',
#    'appears',
#    'appears',
#    'appears',
#    'mentioned',
#    'POV',
#    'POV'],
#   'pageSize': 51501},
#  {'name': 'Barsena',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Barsena Blackhair'],
#   'books': [5, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 8716},
#  {'name': 'Barth',
#   'fullname': None,
#   'titles': ['Septon', 'Hand of the King'],
#   'aliases': None,
#   'books': [0, 0, 0, 3, 4, 5, 0],
#   'roleInBooks': ['mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned'],
#   'pageSize': 24127},
#  {'name': 'Barthogan Stark',
#   'fullname': None,
#   'titles': ['Lord of Winterfell', 'Warden of the North'],
#   'aliases': ['Barth Blacksword'],
#   'books': [0, 2, 0],
#   'roleInBooks': ['mentioned', 'mentioned'],
#   'pageSize': 10374},
#  {'name': 'Barth',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [2, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7506},
#  {'name': 'Bass',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [1, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 7820},
#  {'name': 'Bayard Norcross',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [4, 5, 0],
#   'roleInBooks': ['mentioned', 'mentioned'],
#   'pageSize': 8765},
#  {'name': 'Bearded Ben',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [4, 5, 0],
#   'roleInBooks': ['appendix', 'appears'],
#   'pageSize': 7986},
#  {'name': 'Beardless Dick',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [3, 4, 0],
#   'roleInBooks': ['appears', 'appendix'],
#   'pageSize': 8017},
#  {'name': 'Becca',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [1, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7452},
#  {'name': 'Becca',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Becca the Baker'],
#   'books': [3, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7841},
#  {'name': 'Beck',
#   'fullname': None,
#   'titles': ['Goodman'],
#   'aliases': None,
#   'books': [3, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7606},
#  {'name': 'Bedwyck',
#   'fullname': None,
#   'titles': ['Commander of Icemark'],
#   'aliases': ['Giant'],
#   'books': [2, 3, 4, 5, 0],
#   'roleInBooks': ['appears', 'appears', 'appendix', 'appears'],
#   'pageSize': 9499},
#  {'name': 'Belandra',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [4, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7765},
#  {'name': 'Belaquo',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Belaquo Bonebreaker'],
#   'books': [5, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 8553},
#  {'name': 'Beldecar',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [0, 3, 0],
#   'roleInBooks': ['mentioned', 'mentioned'],
#   'pageSize': 7572},
#  {'name': 'Lord Belgrave',
#   'fullname': None,
#   'titles': ['Lord'],
#   'aliases': None,
#   'books': [3, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7903},
#  {'name': 'Belis',
#   'fullname': None,
#   'titles': ['Wisdom'],
#   'aliases': None,
#   'books': [3, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 8301},
#  {'name': 'Bella',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [3, 4, 0],
#   'roleInBooks': ['appears', 'appendix'],
#   'pageSize': 9679},
#  {'name': 'Bellegere Otherys',
#   'fullname': None,
#   'titles': ['Captain of Widow Wind'],
#   'aliases': ['the Black Pearl of Braavos'],
#   'books': [0, 4, 0, 0],
#   'roleInBooks': ['mentioned', 'mentioned', 'mentioned'],
#   'pageSize': 10219},
#  {'name': 'Bellegere Otherys',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Black Pearl of Braavos', 'Brown Pearl'],
#   'books': [4, 0, 0],
#   'roleInBooks': ['mentioned', 'appears'],
#   'pageSize': 9721},
#  {'name': 'Bellena Hawick',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [2, 3, 4, 0],
#   'roleInBooks': ['appendix', 'appendix', 'appendix'],
#   'pageSize': 8890},
#  {'name': 'Bellonara Otherys',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Black Pearl of Braavos'],
#   'books': [4, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 8782},
#  {'name': 'Belwas',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Strong Belwas', 'Belwas the Strong'],
#   'books': [2, 3, 4, 5, 0],
#   'roleInBooks': ['appears', 'appears', 'appendix', 'appears'],
#   'pageSize': 13961},
#  {'name': 'Ben',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [4, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 7749},
#  {'name': 'Benedar Belmore',
#   'fullname': None,
#   'titles': ['Lord of Strongsong'],
#   'aliases': None,
#   'books': [4, 5, 0, 0],
#   'roleInBooks': ['appears', 'appendix', 'appears'],
#   'pageSize': 9701},
#  {'name': 'Benedict',
#   'fullname': None,
#   'titles': ['Archmaester'],
#   'aliases': None,
#   'books': [4, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7618},
#  {'name': 'Benedict Broom',
#   'fullname': None,
#   'titles': ['Ser', 'Master-at-arms at Casterly Rock'],
#   'aliases': None,
#   'books': [3, 4, 5, 0],
#   'roleInBooks': ['appendix', 'appendix', 'appendix'],
#   'pageSize': 7811},
#  {'name': 'Benfred Tallhart',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [2, 3, 4, 5, 0],
#   'roleInBooks': ['appears', 'appendix', 'appendix', 'appendix'],
#   'pageSize': 10116},
#  {'name': 'Benfrey Frey',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [2, 3, 4, 5, 0],
#   'roleInBooks': ['appendix', 'appears', 'appendix', 'appendix'],
#   'pageSize': 9536},
#  {'name': 'Benjen Stark',
#   'fullname': None,
#   'titles': ['First Ranger'],
#   'aliases': ['Uncle Benjen', 'Ben Stark', 'The young pup'],
#   'books': [0, 1, 2, 3, 5, 0],
#   'roleInBooks': ['appendix',
#    'appears',
#    'mentioned',
#    'mentioned',
#    'mentioned'],
#   'pageSize': 17178},
#  {'name': 'Benjen Stark',
#   'fullname': 'Benjen Stark',
#   'titles': ['King in the North', 'Lord of Winterfell'],
#   'aliases': ['Benjen the Bitter'],
#   'books': [2, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7865},
#  {'name': 'Benjen Stark',
#   'fullname': 'Benjen Stark',
#   'titles': ['King in the North', 'Lord of Winterfell'],
#   'aliases': ['Benjen the Sweet'],
#   'books': [2, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7857},
#  {'name': 'Bennard Brune',
#   'fullname': None,
#   'titles': ['Ser', 'The Knight of Brownhollow'],
#   'aliases': None,
#   'books': [4, 0],
#   'roleInBooks': ['appendix'],
#   'pageSize': 7808},
#  {'name': 'Bennarion Botley',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [4, 0],
#   'roleInBooks': ['appendix'],
#   'pageSize': 8427},
#  {'name': 'Bennet',
#   'fullname': None,
#   'titles': ['Septon'],
#   'aliases': None,
#   'books': [4, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7774},
#  {'name': 'Bennis',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': ['Bennis of the Brown Shield', 'Bennis Brownstench'],
#   'books': [0, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 9758},
#  {'name': 'Big Belly Ben',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Big Belly Ben'],
#   'books': [3, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 8009},
#  {'name': 'Ben',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Ben Blackthumb'],
#   'books': [2, 4, 0],
#   'roleInBooks': ['mentioned', 'mentioned'],
#   'pageSize': 8341},
#  {'name': 'Ben',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Ben Bones'],
#   'books': [5, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 8497},
#  {'name': 'Ben Bushy',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': ['Big Ben'],
#   'books': [4, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 8510},
#  {'name': 'Ben Buttercakes',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [0, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 8246},
#  {'name': 'Ben Plumm',
#   'fullname': None,
#   'titles': ['Captain of the Second Sons', 'Commander of the Second Sons'],
#   'aliases': ['Brown Ben Plumm'],
#   'books': [3, 4, 5, 0, 0],
#   'roleInBooks': ['appears', 'appendix', 'appears', 'appears'],
#   'pageSize': 13258},
#  {'name': 'Beqqo',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [4, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7566},
#  {'name': 'Berena Hornwood',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [2, 3, 4, 5, 0],
#   'roleInBooks': ['mentioned', 'appendix', 'appendix', 'appendix'],
#   'pageSize': 8608},
#  {'name': 'Beren Tallhart',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [2, 3, 4, 5, 0],
# ...
#   'fullname': None,
#   'titles': ['Lord of the Eyrie',
#    'Defender of the Vale',
#    'Warden of the East',
#    'Hand of the King',
#    'Keeper of the Gates of the Moon',
#    'Ser'],
#   'aliases': None,
#   'books': [0, 1, 2, 3, 4, 5, 0, 0],
#   'roleInBooks': ['mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned',
#    'mentioned'],
#   'pageSize': 32079},
#  {'name': 'Jon Bettley',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': ['Beardless Jon'],
#   'books': [4, 5, 0],
#   'roleInBooks': ['appears', 'appendix'],
#   'pageSize': 8499},
#  {'name': 'Jon Brax',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [2, 3, 4, 0],
#   'roleInBooks': ['appendix', 'appendix', 'appendix'],
#   'pageSize': 8056},
#  {'name': 'Jon Bulwer',
#   'fullname': None,
#   'titles': ['Lord of Blackcrown'],
#   'aliases': None,
#   'books': [3, 4, 0],
#   'roleInBooks': ['appendix', 'appendix'],
#   'pageSize': 7972},
#  {'name': 'Jon Connington',
#   'fullname': None,
#   'titles': ["Lord of Griffin's Roost",
#    'Hand of the King',
#    'Hand of the True King'],
#   'aliases': ['Griff', 'The dancing griffins Hand'],
#   'books': [0, 3, 4, 5, 0],
#   'roleInBooks': ['mentioned', 'mentioned', 'mentioned', 'POV'],
#   'pageSize': 30520},
#  {'name': 'Jon Cupps',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [4, 0],
#   'roleInBooks': ['appendix'],
#   'pageSize': 7524},
#  {'name': 'Jon Fossoway',
#   'fullname': None,
#   'titles': ['The Knight of New Barrel', 'Ser'],
#   'aliases': None,
#   'books': [2, 0, 5, 0],
#   'roleInBooks': ['appears', 'appendix', 'appendix'],
#   'pageSize': 9677},
#  {'name': 'Jon Heddle',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': ['Long Jon'],
#   'books': [4, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 8151},
#  {'name': 'Jon Hollard',
#   'fullname': None,
#   'titles': ['Ser', 'Steward of the Dun Fort'],
#   'aliases': None,
#   'books': [4, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 8589},
#  {'name': 'Jon Lynderly',
#   'fullname': None,
#   'titles': ['Lord of the Snakewood'],
#   'aliases': None,
#   'books': [4, 5, 0],
#   'roleInBooks': ['mentioned', 'appendix'],
#   'pageSize': 7966},
#  {'name': 'Jon Myre',
#   'fullname': None,
#   'titles': ['Captain'],
#   'aliases': ['Pinchface Jon'],
#   'books': [3, 4, 5, 0, 0],
#   'roleInBooks': ['appendix', 'appears', 'appendix', 'appears'],
#   'pageSize': 8747},
#  {'name': 'Jon',
#   'fullname': None,
#   'titles': None,
#   'aliases': ["Jon O' Nutten"],
#   'books': [4, 0],
#   'roleInBooks': ['appendix'],
#   'pageSize': 7714},
#  {'name': 'Jon Penny',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [4, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7810},
#  {'name': 'Jon Penrose',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [0, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 7713},
#  {'name': 'Jon Pox',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [4, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7951},
#  {'name': 'Jon Redfort',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [4, 5, 0],
#   'roleInBooks': ['appendix', 'appendix'],
#   'pageSize': 7901},
#  {'name': 'Jon Snow',
#   'fullname': None,
#   'titles': ["Lord Commander of the Night's Watch"],
#   'aliases': ['Lord Snow',
#    "Ser Alliser's Bane",
#    'The Snow of Winterfell',
#    'The crow-come-over',
#    'The Bastard of Winterfell',
#    'Lord Crow',
#    'The Black Bastard of the Wall'],
#   'books': [1, 2, 3, 4, 5, 0],
#   'roleInBooks': ['POV', 'POV', 'POV', 'appears', 'POV'],
#   'pageSize': 50589},
#  {'name': 'Jon Umber',
#   'fullname': None,
#   'titles': ['Lord of the Last Hearth'],
#   'aliases': ['The Greatjon', 'Greatjon Umber'],
#   'books': [1, 2, 3, 4, 5, 0],
#   'roleInBooks': ['appears', 'appears', 'appears', 'appendix', 'mentioned'],
#   'pageSize': 15976},
#  {'name': 'Jon Umber',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['The Smalljon', 'Smalljon Umber'],
#   'books': [1, 2, 3, 4, 5, 0],
#   'roleInBooks': ['appears', 'appendix', 'appears', 'appendix', 'appendix'],
#   'pageSize': 10515},
#  {'name': 'Jon Vance',
#   'fullname': None,
#   'titles': ['Maester'],
#   'aliases': None,
#   'books': [4, 0],
#   'roleInBooks': ['appendix'],
#   'pageSize': 8061},
#  {'name': 'Jon Waters',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [0, 4, 0],
#   'roleInBooks': ['mentioned', 'mentioned'],
#   'pageSize': 9330},
#  {'name': 'Jon Wylde',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [2, 3, 4, 0],
#   'roleInBooks': ['appendix', 'appendix', 'appendix'],
#   'pageSize': 7973},
#  {'name': 'Jorah Mormont',
#   'fullname': None,
#   'titles': ['Ser', 'Lord of Bear Island'],
#   'aliases': ['The exile knight', 'Jorah the Andal', 'Ser Bezoar'],
#   'books': [1, 2, 3, 4, 5, 0, 0],
#   'roleInBooks': ['appears',
#    'appears',
#    'appears',
#    'appendix',
#    'appears',
#    'appears'],
#   'pageSize': 40263},
#  {'name': 'Jorah Stark',
#   'fullname': None,
#   'titles': ['King in the North', 'Lord of Winterfell'],
#   'aliases': None,
#   'books': [2, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7635},
#  {'name': 'Joramun',
#   'fullname': None,
#   'titles': ['King-Beyond-the-Wall'],
#   'aliases': None,
#   'books': [0, 2, 3, 5, 0],
#   'roleInBooks': ['mentioned', 'mentioned', 'mentioned', 'mentioned'],
#   'pageSize': 9015},
#  {'name': 'Jorelle Mormont',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Jory'],
#   'books': [4, 5, 0],
#   'roleInBooks': ['appendix', 'mentioned'],
#   'pageSize': 8624},
#  {'name': 'Jorgen',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [0, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 7893},
#  {'name': 'Jorquen',
#   'fullname': None,
#   'titles': ['Septon'],
#   'aliases': None,
#   'books': [4, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7625},
#  {'name': 'Jory Cassel',
#   'fullname': None,
#   'titles': ['Captain of the guard'],
#   'aliases': None,
#   'books': [1, 2, 3, 5, 0],
#   'roleInBooks': ['appears', 'mentioned', 'mentioned', 'mentioned'],
#   'pageSize': 12853},
#  {'name': 'Joseran',
#   'fullname': None,
#   'titles': ['Maester at Blacktyde Castle'],
#   'aliases': None,
#   'books': [4, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7670},
#  {'name': 'Joseth',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [1, 2, 0],
#   'roleInBooks': ['appears', 'appears'],
#   'pageSize': 8197},
#  {'name': 'Joseth Mallister',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [0, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 7767},
#  {'name': 'Josmyn Peckledon',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Peck'],
#   'books': [2, 3, 4, 5, 0],
#   'roleInBooks': ['appears', 'appears', 'appears', 'appears'],
#   'pageSize': 9395},
#  {'name': 'Joss',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [1, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 7882},
#  {'name': 'Joss Stilwood',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [1, 2, 4, 0],
#   'roleInBooks': ['appears', 'mentioned', 'mentioned'],
#   'pageSize': 8802},
#  {'name': 'Joss',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Joss the Gloom'],
#   'books': [4, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7751},
#  {'name': 'Josua Willum',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [2, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 8838},
#  {'name': 'Jothos Slynt',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [1, 2, 3, 0],
#   'roleInBooks': ['mentioned', 'mentioned', 'appears'],
#   'pageSize': 9387},
#  {'name': 'Joth Quickbow',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [3, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7692},
#  {'name': 'Joyeuse Erenford',
#   'fullname': None,
#   'titles': ['Lady of the Crossing'],
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5, 0],
#   'roleInBooks': ['appears', 'appendix', 'appears', 'appendix', 'appendix'],
#   'pageSize': 8770},
#  {'name': 'Joy Hill',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [0, 1, 2, 3, 4, 5, 0],
#   'roleInBooks': ['appendix',
#    'appendix',
#    'appendix',
#    'mentioned',
#    'mentioned',
#    'appendix'],
#   'pageSize': 10238},
#  {'name': 'Jurne',
#   'fullname': None,
#   'titles': ["Maester at Storm's End"],
#   'aliases': None,
#   'books': [2, 3, 4, 0],
#   'roleInBooks': ['appendix', 'appendix', 'appendix'],
#   'pageSize': 7971},
#  {'name': 'Justin Massey',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': ['the smiler'],
#   'books': [4, 5, 0, 0],
#   'roleInBooks': ['appendix', 'appears', 'appears'],
#   'pageSize': 15509},
#  {'name': 'Jyana',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [4, 5, 0],
#   'roleInBooks': ['appendix', 'appendix'],
#   'pageSize': 7872},
#  {'name': 'Jyanna Frey',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [2, 3, 4, 0],
#   'roleInBooks': ['appendix', 'appendix', 'appendix'],
#   'pageSize': 8340},
#  {'name': 'Jyck',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [1, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 9346},
#  {'name': 'Jynessa Blackmont',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [3, 4, 0],
#   'roleInBooks': ['appears', 'appendix'],
#   'pageSize': 8197},
#  {'name': 'Jyzene',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [3, 4, 0],
#   'roleInBooks': ['appears', 'appendix'],
#   'pageSize': 7410},
#  {'name': 'Kaeth',
#   'fullname': None,
#   'titles': ['Grand Maester'],
#   'aliases': None,
#   'books': [0, 3, 4, 0],
#   'roleInBooks': ['mentioned', 'mentioned', 'mentioned'],
#   'pageSize': 11855},
#  {'name': 'Karlon Stark',
#   'fullname': None,
#   'titles': ["Lord of Karl's Hold"],
#   'aliases': ['Karl'],
#   'books': [3, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7912},
#  {'name': 'Karyl Vance',
#   'fullname': None,
#   'titles': ['Ser', "Lord of Wayfarer's Rest"],
#   'aliases': None,
#   'books': [1, 2, 3, 4, 5, 0],
#   'roleInBooks': ['appears', 'mentioned', 'appears', 'appears', 'appendix'],
#   'pageSize': 10643},
#  {'name': 'Kedge Whiteye',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [3, 4, 5, 0],
#   'roleInBooks': ['appears', 'appears', 'appears'],
#   'pageSize': 10014},
#  {'name': 'Kedry',
#   'fullname': None,
#   'titles': ['Maester'],
#   'aliases': None,
#   'books': [4, 5, 0],
#   'roleInBooks': ['mentioned', 'mentioned'],
#   'pageSize': 9036},
#  {'name': 'Kegs',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [3, 4, 5, 0],
#   'roleInBooks': ['appears', 'appendix', 'appears'],
#   'pageSize': 8534},
#  {'name': 'Kella',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [3, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 8160},
#  {'name': 'Kemmett Pyke',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Kemmett the Bastard'],
#   'books': [4, 5, 0],
#   'roleInBooks': ['mentioned', 'appendix'],
#   'pageSize': 7833},
#  {'name': 'Kenned',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Kenned the Whale'],
#   'books': [2, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 8262},
#  {'name': 'Kennos of Kayce',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [3, 4, 5, 0],
#   'roleInBooks': ['appears', 'appears', 'appears'],
#   'pageSize': 9364},
#  {'name': 'Ketter',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [1, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 7721},
#  {'name': 'Kevan Lannister',
#   'fullname': None,
#   'titles': ['Ser', 'Master of laws', 'Lord Regent', 'Protector of the Realm'],
#   'aliases': None,
#   'books': [0, 1, 2, 3, 4, 5, 0],
#   'roleInBooks': ['mentioned',
#    'appears',
#    'appears',
#    'appears',
#    'appears',
#    'POV'],
#   'pageSize': 32847},
#  {'name': 'Kezmya Pahl',
#   'fullname': None,
#   'titles': ['Cupbearer'],
#   'aliases': None,
#   'books': [5, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 9069},
#  {'name': 'Khorane Sathmantes',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [3, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 8008},
#  {'name': 'Khrazz',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [5, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 8879},
#  {'name': 'The Kindly Man',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['The Kindly Man'],
#   'books': [4, 5, 0],
#   'roleInBooks': ['appears', 'appears'],
#   'pageSize': 10313},
#  {'name': 'Kirby Pimm',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [0, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 7829},
#  {'name': 'Kirth Vance',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [3, 4, 0],
#   'roleInBooks': ['appendix', 'appendix'],
#   'pageSize': 8262},
#  {'name': 'Kojja Mo',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [4, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 10410},
#  {'name': 'Koss',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [2, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 10503},
#  {'name': 'Kraznys mo Nakloz',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [3, 5, 0],
#   'roleInBooks': ['appears', 'mentioned'],
#   'pageSize': 9712},
#  {'name': 'Khrazz',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [5, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 9013},
#  {'name': 'Kromm',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [2, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 8053},
#  {'name': 'Kurleket',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [1, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 8304},
#  {'name': 'Kurz',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [2, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 10054},
#  {'name': 'Kyle',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': ['Cat of Misty Moor', 'Kyle the Cat'],
#   'books': [0, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 8339},
#  {'name': 'Kyleg',
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Kyleg of the Wooden Ear'],
#   'books': [5, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 7672},
#  {'name': 'Kyle',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [3, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 8056},
#  {'name': 'Kyle Condon',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [3, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 8028},
#  {'name': 'Kyle Royce',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [2, 0],
#   'roleInBooks': ['mentioned'],
#   'pageSize': 8153},
#  {'name': 'Kym',
#   'fullname': None,
#   'titles': ['Maester'],
#   'aliases': None,
#   'books': [2, 3, 0],
#   'roleInBooks': ['mentioned', 'mentioned'],
#   'pageSize': 7774},
#  {'name': 'Kyra',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [1, 2, 4, 5, 0],
#   'roleInBooks': ['appears', 'appears', 'appendix', 'mentioned'],
#   'pageSize': 10745},
#  {'name': 'Kyra Frey',
#   'fullname': None,
#   'titles': None,
#   'aliases': None,
#   'books': [2, 3, 4, 0],
#   'roleInBooks': ['appendix', 'mentioned', 'appendix'],
#   'pageSize': 8591},
#  {'name': 'Lady of the Leaves',
#   'fullname': None,
#   'titles': ['Lady of the Leaves'],
#   'aliases': None,
#   'books': [3, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 8375},
#  {'name': 'Laena Velaryon',
#   'fullname': None,
#   'titles': ['Lady'],
#   'aliases': None,
#   'books': [0, 0, 0, 0, 0],
#   'roleInBooks': ['mentioned', 'mentioned', 'mentioned', 'mentioned'],
#   'pageSize': 14468},
#  {'name': 'Laenor Velaryon',
#   'fullname': None,
#   'titles': ['Ser', 'Prince consort'],
#   'aliases': None,
#   'books': [0, 0, 0, 0, 0],
#   'roleInBooks': ['mentioned', 'mentioned', 'mentioned', 'mentioned'],
#   'pageSize': 16728},
#  {'name': 'Lambert Turnberry',
#   'fullname': None,
#   'titles': ['Ser'],
#   'aliases': None,
#   'books': [4, 5, 0],
#   'roleInBooks': ['appears', 'mentioned'],
#   'pageSize': 9202},
#  {'name': None,
#   'fullname': None,
#   'titles': None,
#   'aliases': ['Lamprey'],
#   'books': [3, 0],
#   'roleInBooks': ['appears'],
#   'pageSize': 8206},
#  ...]

# %%
role = set()
for record in records:
    try:
        for r in record['roleInBooks']:
            role.add(r)
    except:
        pass
role
# Out:
# {'Appears',
#  'Mentioned',
#  'POV',
#  'apendix',
#  'appears',
#  'appendix',
#  'mentioned',
#  'mentions'}

# %%
import pandas as pd
df = pd.DataFrame.from_dict(records)

# %%
df
# Out:
#                                                 aliases  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                       [Addam of Hull]
# 4                                [Bastard of Cornfield]
# 5                                                  None
# 6                                     [Aegon Bloodborn]
# 7                                          [Jinglebell]
# 8     [Aegon the Younger, Aegon the Dragonbane, Aego...
# 9                  [Aegon the Elder, Aegon the Usurper]
# 10                                 [Aegon the Unworthy]
# 11    [Aegon the Conqueror, Aegon the Dragonlord, Ae...
# 12                 [The pretender, Aegon the Uncrowned]
# 13                                                 None
# 14                                                 None
# 15                                        [Young Griff]
# 16    [Aegon the Unlikely, Aegon the Fortunate, Egg,...
# 17                                        [Bittersteel]
# 18                                  [Aelinor Targaryen]
# 19                                                 None
# 20               [Aemond One-Eye, Aemond the Kinslayer]
# 21                                                 None
# 22                                                 None
# 23                                                 None
# 24                                                 None
# 25                     [Aemon Targaryen, Uncle Maester]
# 26              [The Dragonknight, The Knight of Tears]
# 27                                                 None
# 28                                   [King Abomination]
# 29    [Aerion Brightflame, Aerion Brightfire, Aerion...
# ...                                                 ...
# 1503                             [Raymun the Reluctant]
# 1504                                               None
# 1505                                               None
# 1506                                               None
# 1507                                               None
# 1508                                          [Redtusk]
# 1509                                               None
# 1510                         [Red Alyn of the Rosewood]
# 1511                                         [Red Lamb]
# 1512                                               None
# 1513                                               None
# 1514                                             [Reek]
# 1515                                               None
# 1516                                               None
# 1517    [The King in Highgarden, The King in the South]
# 1518                                               None
# 1519                                               None
# 1520                                               None
# 1521                                               None
# 1522                                               None
# 1523                                               None
# 1524  [Silver prince, The dragon prince, The last dr...
# 1525                                               None
# 1526                [The stallion who mounts the world]
# 1527                                               None
# 1528                                               None
# 1529                                               None
# 1530           [Rhaena of Pentos, Rhaena Corbray, Rhae]
# 1531                                               None
# 1532                                    [Squinty Jeyne]
#
#                                      books  \
# 0                                   [0, 0]
# 1                       [1, 2, 3, 4, 5, 0]
# 2                                   [0, 0]
# 3                             [0, 0, 0, 0]
# 4                             [0, 0, 4, 0]
# 5                             [0, 0, 0, 0]
# 6                          [2, 3, 4, 5, 0]
# 7                          [2, 3, 4, 5, 0]
# 8           [0, 0, 0, 0, 0, 1, 3, 4, 5, 0]
# 9                 [0, 0, 0, 0, 1, 3, 4, 0]
# 10          [0, 0, 0, 0, 1, 2, 3, 4, 5, 0]
# 11    [0, 0, 0, 0, 0, 0, 1, 2, 3, 4, 5, 0]
# 12                            [0, 0, 0, 0]
# 13                               [0, 0, 0]
# 14                               [0, 0, 0]
# 15                   [0, 1, 2, 3, 4, 5, 0]
# 16          [0, 0, 0, 0, 1, 2, 3, 4, 5, 0]
# 17                   [0, 0, 0, 4, 5, 0, 0]
# 18                               [0, 0, 0]
# 19                         [0, 0, 0, 0, 0]
# 20                      [0, 0, 0, 0, 5, 0]
# 21                         [0, 0, 0, 3, 0]
# 22                                  [3, 0]
# 23                         [2, 3, 4, 5, 0]
# 24                            [2, 3, 4, 0]
# 25          [0, 0, 0, 0, 1, 2, 3, 4, 5, 0]
# 26          [0, 0, 0, 0, 1, 2, 3, 4, 5, 0]
# 27                   [1, 2, 3, 4, 5, 0, 0]
# 28                         [0, 0, 0, 1, 0]
# 29                [0, 0, 0, 0, 2, 3, 5, 0]
# ...                                    ...
# 1503                                [0, 0]
# 1504                          [0, 2, 5, 0]
# 1505                             [3, 4, 0]
# 1506                             [4, 5, 0]
# 1507                             [4, 5, 0]
# 1508                                [0, 0]
# 1509                             [0, 2, 0]
# 1510                             [3, 5, 0]
# 1511                             [5, 0, 0]
# 1512                          [4, 5, 0, 0]
# 1513                                [2, 0]
# 1514                          [2, 4, 5, 0]
# 1515                       [1, 3, 4, 5, 0]
# 1516                             [4, 5, 0]
# 1517                 [1, 2, 3, 4, 5, 0, 0]
# 1518                          [2, 3, 4, 0]
# 1519                             [4, 5, 0]
# 1520                                [0, 0]
# 1521                                [2, 0]
# 1522                                [5, 0]
# 1523                       [2, 3, 4, 5, 0]
# 1524              [0, 1, 2, 3, 4, 5, 0, 0]
# 1525                          [0, 0, 0, 0]
# 1526                       [1, 2, 3, 4, 0]
# 1527                 [0, 1, 2, 3, 4, 5, 0]
# 1528                          [0, 4, 5, 0]
# 1529                             [0, 4, 0]
# 1530                       [0, 0, 0, 0, 0]
# 1531                             [0, 0, 0]
# 1532                                [0, 0]
#
#                                     fullname  infoboxSize links  \
# 0                                       None            5    []
# 1                                       None           13    []
# 2                                       None            5    []
# 3                                       None           13    []
# 4                                       None           11    []
# 5                                       None            9    []
# 6                                       None            8    []
# 7                                       None           10    []
# 8      Aegon Targaryen the Third of His Name           69    []
# 9     Aegon Targaryen the Second of His Name           69    []
# 10    Aegon Targaryen the Fourth of His Name           79    []
# 11     Aegon Targaryen the First of His Name           72    []
# 12                                      None           15    []
# 13                                      None            9    []
# 14                                      None            9    []
# 15                                      None           13    []
# 16     Aegon Targaryen the Fifth of His Name           69    []
# 17                                      None           19    []
# 18                                      None           10    []
# 19                                      None           16    []
# 20                                      None           19    []
# 21                                      None           10    []
# 22                                      None            3    []
# 23                                      None            9    []
# 24                                      None            9    []
# 25                                      None           27    []
# 26                                      None           21    []
# 27                                      None           14    []
# 28     Aenys Targaryen the First of His Name           62    []
# 29                                      None           23    []
# ...                                      ...          ...   ...
# 1503                                    None            8    []
# 1504                                    None            8    []
# 1505                                    None            8    []
# 1506                                    None            6    []
# 1507                                    None            5    []
# 1508                                    None            4    []
# 1509                                    None            4    []
# 1510                                    None            7    []
# 1511                                    None            7    []
# 1512                                    None            6    []
# 1513                                    None            5    []
# 1514                                    None            8    []
# 1515                                    None            8    []
# 1516                                    None            8    []
# 1517                                    None           21    []
# 1518                                    None            7    []
# 1519                                    None            5    []
# 1520                                    None            4    []
# 1521                                    None            2    []
# 1522                                    None            7    []
# 1523                                    None           12    []
# 1524                                    None           23    []
# 1525                                    None           14    []
# 1526                                    None            9    []
# 1527                                    None           24    []
# 1528                                    None           13    []
# 1529                                    None           11    []
# 1530                                    None           19    []
# 1531                                    None            8    []
# 1532                                    None            4    []
#
#                      name  pageSize  \
# 0              Addam Frey      8374
# 1          Addam Marbrand     19378
# 2            Addam Osgrey      9010
# 3          Addam Velaryon     14856
# 4            Addison Hill     12768
# 5         Aegon Blackfyre     10509
# 6              Aegon Frey      8455
# 7              Aegon Frey     12998
# 8               Aegon III     46334
# 9                Aegon II     35913
# 10               Aegon IV     35372
# 11                Aegon I     27437
# 12        Aegon Targaryen     15817
# 13        Aegon Targaryen      8459
# 14        Aegon Targaryen      9174
# 15        Aegon Targaryen     40002
# 16                Aegon V     24048
# 17           Aegor Rivers     16101
# 18        Aelinor Penrose     11939
# 19            Aemma Arryn     12296
# 20       Aemond Targaryen     20175
# 21        Aemon Blackfyre     10532
# 22         Aemon Costayne      7739
# 23        Aemon Estermont      8820
# 24           Aemon Rivers      8643
# 25                  Aemon     21239
# 26        Aemon Targaryen     24918
# 27             Aenys Frey     14880
# 28                Aenys I     25070
# 29       Aerion Targaryen     14999
# ...                   ...       ...
# 1503      Raymun Fossoway      9679
# 1504      Raymun Redbeard      9594
# 1505   Raynald Westerling     11666
# 1506              Raynard      8538
# 1507     Raynard Ruttiger      8162
# 1508              Redtusk      7901
# 1509               Redwyn      7930
# 1510             Red Alyn      8194
# 1511             Red Lamb      8915
# 1512          Red Oarsman      9483
# 1513            Red Rolfe      7950
# 1514                 Heke     12906
# 1515      Regenard Estren      8376
# 1516       Renfred Rykker      7939
# 1517      Renly Baratheon     31763
# 1518       Renly Norcross      8046
# 1519  Rennifer Longwaters      8951
# 1520       Reynard Webber      7598
# 1521               Reysen      9727
# 1522     Reznak mo Reznak      9621
# 1523         Rhaegar Frey     12460
# 1524    Rhaegar Targaryen     33474
# 1525    Rhaegel Targaryen      9881
# 1526               Rhaego     10887
# 1527    Rhaella Targaryen     19537
# 1528    Rhaelle Targaryen     11147
# 1529     Rhaena Targaryen     11298
# 1530     Rhaena Targaryen     13283
# 1531       Rhae Targaryen      9811
# 1532                Jeyne      7540
#
#                                             roleInBooks  roleScore  \
# 0                                             [appears]        0.8
# 1        [appears, appears, appears, appears, appendix]        3.4
# 2                                           [mentioned]        0.5
# 3                     [mentioned, mentioned, mentioned]        1.5
# 4                     [mentioned, mentioned, mentioned]        1.5
# 5                     [mentioned, mentioned, mentioned]        1.5
# 6          [mentioned, mentioned, mentioned, mentioned]        2.0
# 7             [mentioned, appears, appendix, mentioned]        2.0
# 8     [mentioned, mentioned, mentioned, mentioned, m...        4.5
# 9     [mentioned, mentioned, mentioned, mentioned, m...        3.5
# 10    [mentioned, mentioned, mentioned, mentioned, m...        4.5
# 11    [mentioned, mentioned, mentioned, mentioned, m...        5.5
# 12                    [mentioned, mentioned, mentioned]        1.5
# 13                               [mentioned, mentioned]        1.0
# 14                                [appendix, mentioned]        0.7
# 15    [mentioned, mentioned, mentioned, mentioned, m...        3.3
# 16    [mentioned, appears, appears, appears, mention...        5.4
# 17    [mentioned, mentioned, mentioned, mentioned, m...        3.0
# 18                               [mentioned, mentioned]        1.0
# 19         [mentioned, mentioned, mentioned, mentioned]        2.0
# 20    [mentioned, mentioned, mentioned, mentioned, m...        2.5
# 21         [mentioned, mentioned, mentioned, mentioned]        2.0
# 22                                          [mentioned]        0.5
# 23             [appendix, appendix, appendix, appendix]        0.8
# 24                      [appendix, mentioned, appendix]        0.9
# 25    [mentioned, mentioned, mentioned, mentioned, a...        5.7
# 26    [mentioned, mentioned, mentioned, mentioned, m...        4.5
# 27    [appears, appears, appears, mentioned, appears...        4.2
# 28          [mentioned, mentioned, mentioned, appendix]        1.7
# 29    [mentioned, appears, mentioned, mentioned, men...        3.8
# ...                                                 ...        ...
# 1503                                          [appears]        0.8
# 1504                  [mentioned, mentioned, mentioned]        1.5
# 1505                               [appears, mentioned]        1.3
# 1506                             [mentioned, mentioned]        1.0
# 1507                             [mentioned, mentioned]        1.0
# 1508                                        [mentioned]        0.5
# 1509                             [mentioned, mentioned]        1.0
# 1510                             [mentioned, mentioned]        1.0
# 1511                                 [appears, appears]        1.6
# 1512                    [mentioned, mentioned, appears]        1.8
# 1513                                          [appears]        0.8
# 1514                   [mentioned, appendix, mentioned]        1.2
# 1515       [mentioned, mentioned, mentioned, mentioned]        2.0
# 1516                             [mentioned, mentioned]        1.0
# 1517  [appears, appears, mentioned, mentioned, menti...        3.6
# 1518                  [mentioned, mentioned, mentioned]        1.5
# 1519                             [mentioned, mentioned]        1.0
# 1520                                        [mentioned]        0.5
# 1521                                          [appears]        0.8
# 1522                                          [appears]        0.8
# 1523            [appendix, appendix, appendix, appears]        1.4
# 1524  [mentioned, mentioned, mentioned, mentioned, m...        3.5
# 1525                  [mentioned, mentioned, mentioned]        1.5
# 1526       [mentioned, mentioned, mentioned, mentioned]        2.0
# 1527  [mentioned, mentioned, mentioned, mentioned, m...        3.0
# 1528                  [mentioned, mentioned, mentioned]        1.5
# 1529                             [mentioned, mentioned]        1.0
# 1530       [mentioned, mentioned, mentioned, mentioned]        2.0
# 1531                             [mentioned, mentioned]        1.0
# 1532                                        [mentioned]        0.5
#
#                                                  titles
# 0                                                 [Ser]
# 1                    [Ser, Commander of the City Watch]
# 2                                                  None
# 3                                                 [Ser]
# 4               [Ser, Lord Commander of the Kingsguard]
# 5                                                  None
# 6                                                  None
# 7                                                  None
# 8     [King of the Andals, the Rhoynar, and the Firs...
# 9     [King of the Andals, the Rhoynar, and the Firs...
# 10    [King of the Andals, the Rhoynar, and the Firs...
# 11    [King of All Westeros, Shield of His People, K...
# 12                              [Prince of Dragonstone]
# 13                                             [Prince]
# 14                                             [Prince]
# 15                                                 None
# 16    [King of the Andals, the Rhoynar, and the Firs...
# 17                                                [Ser]
# 18                                        [Lady, Queen]
# 19                                        [Lady, Queen]
# 20      [Prince, Protector of the Realm, Prince Regent]
# 21                                                 None
# 22                                                 None
# 23                                                [Ser]
# 24                                                [Ser]
# 25    [Prince, Maester at Dragonstone, Maester at Ca...
# 26      [Prince, Ser, Lord Commander of the Kingsguard]
# 27                                                [Ser]
# 28    [King of the Andals, the Rhoynar, and the Firs...
# 29                                             [Prince]
# ...                                                 ...
# 1503                                              [Ser]
# 1504                             [King-Beyond-the-Wall]
# 1505                                              [Ser]
# 1506                                           [Septon]
# 1507                                              [Ser]
# 1508                                              [Ser]
# 1509                                               None
# 1510                                               None
# 1511                                              [Ser]
# 1512                                          [Captain]
# 1513                                               None
# 1514                                               None
# 1515                                 [Lord of Wyndhall]
# 1516                               [Lord of Duskendale]
# 1517  [Lord Paramount of the Stormlands, Lord of Sto...
# 1518                                               None
# 1519                                [Chief Undergaoler]
# 1520                                 [Lord of Coldmoat]
# 1521                                               None
# 1522                             [Seneschal of Meereen]
# 1523                                               None
# 1524                       [Prince of Dragonstone, Ser]
# 1525                            [Prince of Dragonstone]
# 1526                                               None
# 1527                   [Princess, Queen, Dowager Queen]
# 1528                                         [Princess]
# 1529                                  [Princess, Septa]
# 1530                                   [Lady, Princess]
# 1531                                         [Princess]
# 1532                                               None
#
# [1533 rows x 10 columns]

# %%
df.describe()
# Out:
#        infoboxSize      pageSize    roleScore
# count  1533.000000   1533.000000  1521.000000
# mean      9.298761  10605.991520     1.394149
# std       9.272252   5735.613766     1.000019
# min       0.000000   6133.000000     0.200000
# 25%       5.000000   8007.000000     0.700000
# 50%       7.000000   8762.000000     1.000000
# 75%      10.000000  10483.000000     1.800000
# max      95.000000  62517.000000     6.200000

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
score = scaler.fit_transform(df[['infoboxSize', 'pageSize', 'roleScore']])
# Out:
# C:\Users\alexa\Documents\UTC\IM04 - Depart etranger\Anaconda\Ananas\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
from scipy.spatial import distance
import numpy as np

scores = []

for s in score:
    try:
        np.asarray_chkfinite(s)
        scores.append(distance.euclidean(s, [0, 0, 0]))
    except ValueError:
        scores.append(0.0)
df['score'] = scores

# %%
df
# Out:
#                                                 aliases  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                       [Addam of Hull]
# 4                                [Bastard of Cornfield]
# 5                                                  None
# 6                                     [Aegon Bloodborn]
# 7                                          [Jinglebell]
# 8     [Aegon the Younger, Aegon the Dragonbane, Aego...
# 9                  [Aegon the Elder, Aegon the Usurper]
# 10                                 [Aegon the Unworthy]
# 11    [Aegon the Conqueror, Aegon the Dragonlord, Ae...
# 12                 [The pretender, Aegon the Uncrowned]
# 13                                                 None
# 14                                                 None
# 15                                        [Young Griff]
# 16    [Aegon the Unlikely, Aegon the Fortunate, Egg,...
# 17                                        [Bittersteel]
# 18                                  [Aelinor Targaryen]
# 19                                                 None
# 20               [Aemond One-Eye, Aemond the Kinslayer]
# 21                                                 None
# 22                                                 None
# 23                                                 None
# 24                                                 None
# 25                     [Aemon Targaryen, Uncle Maester]
# 26              [The Dragonknight, The Knight of Tears]
# 27                                                 None
# 28                                   [King Abomination]
# 29    [Aerion Brightflame, Aerion Brightfire, Aerion...
# ...                                                 ...
# 1503                             [Raymun the Reluctant]
# 1504                                               None
# 1505                                               None
# 1506                                               None
# 1507                                               None
# 1508                                          [Redtusk]
# 1509                                               None
# 1510                         [Red Alyn of the Rosewood]
# 1511                                         [Red Lamb]
# 1512                                               None
# 1513                                               None
# 1514                                             [Reek]
# 1515                                               None
# 1516                                               None
# 1517    [The King in Highgarden, The King in the South]
# 1518                                               None
# 1519                                               None
# 1520                                               None
# 1521                                               None
# 1522                                               None
# 1523                                               None
# 1524  [Silver prince, The dragon prince, The last dr...
# 1525                                               None
# 1526                [The stallion who mounts the world]
# 1527                                               None
# 1528                                               None
# 1529                                               None
# 1530           [Rhaena of Pentos, Rhaena Corbray, Rhae]
# 1531                                               None
# 1532                                    [Squinty Jeyne]
#
#                                      books  \
# 0                                   [0, 0]
# 1                       [1, 2, 3, 4, 5, 0]
# 2                                   [0, 0]
# 3                             [0, 0, 0, 0]
# 4                             [0, 0, 4, 0]
# 5                             [0, 0, 0, 0]
# 6                          [2, 3, 4, 5, 0]
# 7                          [2, 3, 4, 5, 0]
# 8           [0, 0, 0, 0, 0, 1, 3, 4, 5, 0]
# 9                 [0, 0, 0, 0, 1, 3, 4, 0]
# 10          [0, 0, 0, 0, 1, 2, 3, 4, 5, 0]
# 11    [0, 0, 0, 0, 0, 0, 1, 2, 3, 4, 5, 0]
# 12                            [0, 0, 0, 0]
# 13                               [0, 0, 0]
# 14                               [0, 0, 0]
# 15                   [0, 1, 2, 3, 4, 5, 0]
# 16          [0, 0, 0, 0, 1, 2, 3, 4, 5, 0]
# 17                   [0, 0, 0, 4, 5, 0, 0]
# 18                               [0, 0, 0]
# 19                         [0, 0, 0, 0, 0]
# 20                      [0, 0, 0, 0, 5, 0]
# 21                         [0, 0, 0, 3, 0]
# 22                                  [3, 0]
# 23                         [2, 3, 4, 5, 0]
# 24                            [2, 3, 4, 0]
# 25          [0, 0, 0, 0, 1, 2, 3, 4, 5, 0]
# 26          [0, 0, 0, 0, 1, 2, 3, 4, 5, 0]
# 27                   [1, 2, 3, 4, 5, 0, 0]
# 28                         [0, 0, 0, 1, 0]
# 29                [0, 0, 0, 0, 2, 3, 5, 0]
# ...                                    ...
# 1503                                [0, 0]
# 1504                          [0, 2, 5, 0]
# 1505                             [3, 4, 0]
# 1506                             [4, 5, 0]
# 1507                             [4, 5, 0]
# 1508                                [0, 0]
# 1509                             [0, 2, 0]
# 1510                             [3, 5, 0]
# 1511                             [5, 0, 0]
# 1512                          [4, 5, 0, 0]
# 1513                                [2, 0]
# 1514                          [2, 4, 5, 0]
# 1515                       [1, 3, 4, 5, 0]
# 1516                             [4, 5, 0]
# 1517                 [1, 2, 3, 4, 5, 0, 0]
# 1518                          [2, 3, 4, 0]
# 1519                             [4, 5, 0]
# 1520                                [0, 0]
# 1521                                [2, 0]
# 1522                                [5, 0]
# 1523                       [2, 3, 4, 5, 0]
# 1524              [0, 1, 2, 3, 4, 5, 0, 0]
# 1525                          [0, 0, 0, 0]
# 1526                       [1, 2, 3, 4, 0]
# 1527                 [0, 1, 2, 3, 4, 5, 0]
# 1528                          [0, 4, 5, 0]
# 1529                             [0, 4, 0]
# 1530                       [0, 0, 0, 0, 0]
# 1531                             [0, 0, 0]
# 1532                                [0, 0]
#
#                                     fullname  infoboxSize links  \
# 0                                       None            5    []
# 1                                       None           13    []
# 2                                       None            5    []
# 3                                       None           13    []
# 4                                       None           11    []
# 5                                       None            9    []
# 6                                       None            8    []
# 7                                       None           10    []
# 8      Aegon Targaryen the Third of His Name           69    []
# 9     Aegon Targaryen the Second of His Name           69    []
# 10    Aegon Targaryen the Fourth of His Name           79    []
# 11     Aegon Targaryen the First of His Name           72    []
# 12                                      None           15    []
# 13                                      None            9    []
# 14                                      None            9    []
# 15                                      None           13    []
# 16     Aegon Targaryen the Fifth of His Name           69    []
# 17                                      None           19    []
# 18                                      None           10    []
# 19                                      None           16    []
# 20                                      None           19    []
# 21                                      None           10    []
# 22                                      None            3    []
# 23                                      None            9    []
# 24                                      None            9    []
# 25                                      None           27    []
# 26                                      None           21    []
# 27                                      None           14    []
# 28     Aenys Targaryen the First of His Name           62    []
# 29                                      None           23    []
# ...                                      ...          ...   ...
# 1503                                    None            8    []
# 1504                                    None            8    []
# 1505                                    None            8    []
# 1506                                    None            6    []
# 1507                                    None            5    []
# 1508                                    None            4    []
# 1509                                    None            4    []
# 1510                                    None            7    []
# 1511                                    None            7    []
# 1512                                    None            6    []
# 1513                                    None            5    []
# 1514                                    None            8    []
# 1515                                    None            8    []
# 1516                                    None            8    []
# 1517                                    None           21    []
# 1518                                    None            7    []
# 1519                                    None            5    []
# 1520                                    None            4    []
# 1521                                    None            2    []
# 1522                                    None            7    []
# 1523                                    None           12    []
# 1524                                    None           23    []
# 1525                                    None           14    []
# 1526                                    None            9    []
# 1527                                    None           24    []
# 1528                                    None           13    []
# 1529                                    None           11    []
# 1530                                    None           19    []
# 1531                                    None            8    []
# 1532                                    None            4    []
#
#                      name  pageSize  \
# 0              Addam Frey      8374
# 1          Addam Marbrand     19378
# 2            Addam Osgrey      9010
# 3          Addam Velaryon     14856
# 4            Addison Hill     12768
# 5         Aegon Blackfyre     10509
# 6              Aegon Frey      8455
# 7              Aegon Frey     12998
# 8               Aegon III     46334
# 9                Aegon II     35913
# 10               Aegon IV     35372
# 11                Aegon I     27437
# 12        Aegon Targaryen     15817
# 13        Aegon Targaryen      8459
# 14        Aegon Targaryen      9174
# 15        Aegon Targaryen     40002
# 16                Aegon V     24048
# 17           Aegor Rivers     16101
# 18        Aelinor Penrose     11939
# 19            Aemma Arryn     12296
# 20       Aemond Targaryen     20175
# 21        Aemon Blackfyre     10532
# 22         Aemon Costayne      7739
# 23        Aemon Estermont      8820
# 24           Aemon Rivers      8643
# 25                  Aemon     21239
# 26        Aemon Targaryen     24918
# 27             Aenys Frey     14880
# 28                Aenys I     25070
# 29       Aerion Targaryen     14999
# ...                   ...       ...
# 1503      Raymun Fossoway      9679
# 1504      Raymun Redbeard      9594
# 1505   Raynald Westerling     11666
# 1506              Raynard      8538
# 1507     Raynard Ruttiger      8162
# 1508              Redtusk      7901
# 1509               Redwyn      7930
# 1510             Red Alyn      8194
# 1511             Red Lamb      8915
# 1512          Red Oarsman      9483
# 1513            Red Rolfe      7950
# 1514                 Heke     12906
# 1515      Regenard Estren      8376
# 1516       Renfred Rykker      7939
# 1517      Renly Baratheon     31763
# 1518       Renly Norcross      8046
# 1519  Rennifer Longwaters      8951
# 1520       Reynard Webber      7598
# 1521               Reysen      9727
# 1522     Reznak mo Reznak      9621
# 1523         Rhaegar Frey     12460
# 1524    Rhaegar Targaryen     33474
# 1525    Rhaegel Targaryen      9881
# 1526               Rhaego     10887
# 1527    Rhaella Targaryen     19537
# 1528    Rhaelle Targaryen     11147
# 1529     Rhaena Targaryen     11298
# 1530     Rhaena Targaryen     13283
# 1531       Rhae Targaryen      9811
# 1532                Jeyne      7540
#
#                                             roleInBooks  roleScore  \
# 0                                             [appears]        0.8
# 1        [appears, appears, appears, appears, appendix]        3.4
# 2                                           [mentioned]        0.5
# 3                     [mentioned, mentioned, mentioned]        1.5
# 4                     [mentioned, mentioned, mentioned]        1.5
# 5                     [mentioned, mentioned, mentioned]        1.5
# 6          [mentioned, mentioned, mentioned, mentioned]        2.0
# 7             [mentioned, appears, appendix, mentioned]        2.0
# 8     [mentioned, mentioned, mentioned, mentioned, m...        4.5
# 9     [mentioned, mentioned, mentioned, mentioned, m...        3.5
# 10    [mentioned, mentioned, mentioned, mentioned, m...        4.5
# 11    [mentioned, mentioned, mentioned, mentioned, m...        5.5
# 12                    [mentioned, mentioned, mentioned]        1.5
# 13                               [mentioned, mentioned]        1.0
# 14                                [appendix, mentioned]        0.7
# 15    [mentioned, mentioned, mentioned, mentioned, m...        3.3
# 16    [mentioned, appears, appears, appears, mention...        5.4
# 17    [mentioned, mentioned, mentioned, mentioned, m...        3.0
# 18                               [mentioned, mentioned]        1.0
# 19         [mentioned, mentioned, mentioned, mentioned]        2.0
# 20    [mentioned, mentioned, mentioned, mentioned, m...        2.5
# 21         [mentioned, mentioned, mentioned, mentioned]        2.0
# 22                                          [mentioned]        0.5
# 23             [appendix, appendix, appendix, appendix]        0.8
# 24                      [appendix, mentioned, appendix]        0.9
# 25    [mentioned, mentioned, mentioned, mentioned, a...        5.7
# 26    [mentioned, mentioned, mentioned, mentioned, m...        4.5
# 27    [appears, appears, appears, mentioned, appears...        4.2
# 28          [mentioned, mentioned, mentioned, appendix]        1.7
# 29    [mentioned, appears, mentioned, mentioned, men...        3.8
# ...                                                 ...        ...
# 1503                                          [appears]        0.8
# 1504                  [mentioned, mentioned, mentioned]        1.5
# 1505                               [appears, mentioned]        1.3
# 1506                             [mentioned, mentioned]        1.0
# 1507                             [mentioned, mentioned]        1.0
# 1508                                        [mentioned]        0.5
# 1509                             [mentioned, mentioned]        1.0
# 1510                             [mentioned, mentioned]        1.0
# 1511                                 [appears, appears]        1.6
# 1512                    [mentioned, mentioned, appears]        1.8
# 1513                                          [appears]        0.8
# 1514                   [mentioned, appendix, mentioned]        1.2
# 1515       [mentioned, mentioned, mentioned, mentioned]        2.0
# 1516                             [mentioned, mentioned]        1.0
# 1517  [appears, appears, mentioned, mentioned, menti...        3.6
# 1518                  [mentioned, mentioned, mentioned]        1.5
# 1519                             [mentioned, mentioned]        1.0
# 1520                                        [mentioned]        0.5
# 1521                                          [appears]        0.8
# 1522                                          [appears]        0.8
# 1523            [appendix, appendix, appendix, appears]        1.4
# 1524  [mentioned, mentioned, mentioned, mentioned, m...        3.5
# 1525                  [mentioned, mentioned, mentioned]        1.5
# 1526       [mentioned, mentioned, mentioned, mentioned]        2.0
# 1527  [mentioned, mentioned, mentioned, mentioned, m...        3.0
# 1528                  [mentioned, mentioned, mentioned]        1.5
# 1529                             [mentioned, mentioned]        1.0
# 1530       [mentioned, mentioned, mentioned, mentioned]        2.0
# 1531                             [mentioned, mentioned]        1.0
# 1532                                        [mentioned]        0.5
#
#                                                  titles     score
# 0                                                 [Ser]  0.119791
# 1                    [Ser, Commander of the City Watch]  0.598625
# 2                                                  None  0.088734
# 3                                                 [Ser]  0.299340
# 4               [Ser, Lord Commander of the Kingsguard]  0.272395
# 5                                                  None  0.248883
# 6                                                  None  0.314305
# 7                                                  None  0.340447
# 8     [King of the Andals, the Rhoynar, and the Firs...  1.244787
# 9     [King of the Andals, the Rhoynar, and the Firs...  1.053087
# 10    [King of the Andals, the Rhoynar, and the Firs...  1.214104
# 11    [King of All Westeros, Shield of His People, K...  1.223701
# 12                              [Prince of Dragonstone]  0.318392
# 13                                             [Prince]  0.168685
# 14                                             [Prince]  0.137216
# 15                                                 None  0.804047
# 16    [King of the Andals, the Rhoynar, and the Firs...  1.174563
# 17                                                [Ser]  0.537617
# 18                                        [Lady, Queen]  0.198649
# 19                                        [Lady, Queen]  0.360989
# 20      [Prince, Protector of the Realm, Prince Regent]  0.498965
# 21                                                 None  0.327364
# 22                                                 None  0.065639
# 23                                                [Ser]  0.145760
# 24                                                [Ser]  0.156741
# 25    [Prince, Maester at Dragonstone, Maester at Ca...  0.996409
# 26      [Prince, Ser, Lord Commander of the Kingsguard]  0.820654
# 27                                                [Ser]  0.700163
# 28    [King of the Andals, the Rhoynar, and the Firs...  0.775389
# 29                                             [Prince]  0.665838
# ...                                                 ...       ...
# 1503                                              [Ser]  0.145074
# 1504                             [King-Beyond-the-Wall]  0.240424
# 1505                                              [Ser]  0.224348
# 1506                                           [Septon]  0.153578
# 1507                                              [Ser]  0.147793
# 1508                                              [Ser]  0.072499
# 1509                                               None  0.143410
# 1510                                               None  0.156663
# 1511                                              [Ser]  0.249616
# 1512                                          [Captain]  0.280411
# 1513                                               None  0.117510
# 1514                                               None  0.222033
# 1515                                 [Lord of Wyndhall]  0.314124
# 1516                               [Lord of Duskendale]  0.160920
# 1517  [Lord Paramount of the Stormlands, Lord of Sto...  0.759343
# 1518                                               None  0.231355
# 1519                                [Chief Undergaoler]  0.151808
# 1520                                 [Lord of Coldmoat]  0.070342
# 1521                                               None  0.120442
# 1522                             [Seneschal of Meereen]  0.138767
# 1523                                               None  0.261816
# 1524                       [Prince of Dragonstone, Ser]  0.772172
# 1525                            [Prince of Dragonstone]  0.270334
# 1526                                               None  0.325705
# 1527                   [Princess, Queen, Dowager Queen]  0.581476
# 1528                                         [Princess]  0.271253
# 1529                                  [Princess, Septa]  0.198938
# 1530                                   [Lady, Princess]  0.382205
# 1531                                         [Princess]  0.170658
# 1532                                               None  0.069968
#
# [1533 rows x 11 columns]

# %%
import matplotlib.pyplot as plt

# %%
df['score'].plot

# %%
df['score'].hist
# Out:
# <bound method hist_series of 0       0.119791
# 1       0.598625
# 2       0.088734
# 3       0.299340
# 4       0.272395
# 5       0.248883
# 6       0.314305
# 7       0.340447
# 8       1.244787
# 9       1.053087
# 10      1.214104
# 11      1.223701
# 12      0.318392
# 13      0.168685
# 14      0.137216
# 15      0.804047
# 16      1.174563
# 17      0.537617
# 18      0.198649
# 19      0.360989
# 20      0.498965
# 21      0.327364
# 22      0.065639
# 23      0.145760
# 24      0.156741
# 25      0.996409
# 26      0.820654
# 27      0.700163
# 28      0.775389
# 29      0.665838
#           ...
# 1503    0.145074
# 1504    0.240424
# 1505    0.224348
# 1506    0.153578
# 1507    0.147793
# 1508    0.072499
# 1509    0.143410
# 1510    0.156663
# 1511    0.249616
# 1512    0.280411
# 1513    0.117510
# 1514    0.222033
# 1515    0.314124
# 1516    0.160920
# 1517    0.759343
# 1518    0.231355
# 1519    0.151808
# 1520    0.070342
# 1521    0.120442
# 1522    0.138767
# 1523    0.261816
# 1524    0.772172
# 1525    0.270334
# 1526    0.325705
# 1527    0.581476
# 1528    0.271253
# 1529    0.198938
# 1530    0.382205
# 1531    0.170658
# 1532    0.069968
# Name: score, Length: 1533, dtype: float64>

# %%
df.loc[df['score'] > 1.0]
# Out:
#                                                 aliases  \
# 8     [Aegon the Younger, Aegon the Dragonbane, Aego...
# 9                  [Aegon the Elder, Aegon the Usurper]
# 10                                 [Aegon the Unworthy]
# 11    [Aegon the Conqueror, Aegon the Dragonlord, Ae...
# 16    [Aegon the Unlikely, Aegon the Fortunate, Egg,...
# 31                            [The Mad King, King Scab]
# 86    [Good Queen Alysanne, The little maid, The oth...
# 141   [Arya Horseface, Arya Underfoot, Arry, Lumpyhe...
# 163   [Balon the Brave, Balon the Blessed, Balon the...
# 172   [Barristan the Bold, Barristan the Old, Arstan...
# 315                                                None
# 382   [Daenerys Stormborn, Dany, The Unburnt, Mhysa,...
# 384             [Daeron the Good, Daeron the Falseborn]
# 497                      [Ned, The Ned, The quiet wolf]
# 563       [Crow's Eye, Euron Crow's Eye, Euron Croweye]
# 848           [The Conciliator, The Wise, The Old King]
# 853   [Kingslayer, The Lion of Lannister, The Young ...
# 901   [Joffrey the Illborn, The Young Usurper, Aerys...
# 930   [Lord Snow, Ser Alliser's Bane, The Snow of Wi...
# 1130  [Maegor the Cruel, The Prince of Dragonstone, ...
# 1131                                        [The Anvil]
#
#                                      books  \
# 8           [0, 0, 0, 0, 0, 1, 3, 4, 5, 0]
# 9                 [0, 0, 0, 0, 1, 3, 4, 0]
# 10          [0, 0, 0, 0, 1, 2, 3, 4, 5, 0]
# 11    [0, 0, 0, 0, 0, 0, 1, 2, 3, 4, 5, 0]
# 16          [0, 0, 0, 0, 1, 2, 3, 4, 5, 0]
# 31                [0, 1, 2, 3, 4, 5, 0, 0]
# 86          [0, 0, 0, 0, 0, 3, 4, 5, 0, 0]
# 141               [0, 1, 2, 3, 4, 5, 0, 0]
# 163               [0, 1, 2, 3, 4, 5, 0, 0]
# 172               [0, 1, 2, 3, 4, 5, 0, 0]
# 315               [0, 1, 2, 3, 4, 5, 0, 0]
# 382               [0, 1, 2, 3, 4, 5, 0, 0]
# 384         [0, 0, 0, 0, 1, 2, 3, 4, 5, 0]
# 497               [0, 1, 2, 3, 4, 5, 0, 0]
# 563               [0, 1, 2, 3, 4, 5, 0, 0]
# 848      [0, 0, 0, 0, 0, 0, 1, 3, 4, 5, 0]
# 853                  [0, 1, 2, 3, 4, 5, 0]
# 901               [0, 1, 2, 3, 4, 5, 0, 0]
# 930                     [1, 2, 3, 4, 5, 0]
# 1130  [0, 0, 0, 0, 0, 0, 1, 2, 3, 4, 5, 0]
# 1131           [0, 0, 0, 0, 1, 2, 4, 0, 0]
#
#                                                fullname  infoboxSize links  \
# 8                 Aegon Targaryen the Third of His Name           69    []
# 9                Aegon Targaryen the Second of His Name           69    []
# 10               Aegon Targaryen the Fourth of His Name           79    []
# 11                Aegon Targaryen the First of His Name           72    []
# 16                Aegon Targaryen the Fifth of His Name           69    []
# 31               Aerys Targaryen the Second of His Name           72    []
# 86                                                 None           34    []
# 141                                                None           41    []
# 163   Balon Greyjoy, the Ninth of His Name Since the...           95    []
# 172                                                None           30    []
# 315                                                None           31    []
# 382            Daenerys Targaryen the First of Her Name           81    []
# 384             Daeron Targaryen the Second of His Name           68    []
# 497                                                None           32    []
# 563   Euron Greyjoy, the Third of His Name Since the...           85    []
# 848           Jaehaerys Targaryen the First of His Name           81    []
# 853                                                None           31    []
# 901             Joffrey Baratheon the First of His Name           70    []
# 930                                                None           28    []
# 1130             Maegor Targaryen the First of His Name           76    []
# 1131             Maekar Targaryen the First of His Name           69    []
#
#                     name  pageSize  \
# 8              Aegon III     46334
# 9               Aegon II     35913
# 10              Aegon IV     35372
# 11               Aegon I     27437
# 16               Aegon V     24048
# 31              Aerys II     49289
# 86    Alysanne Targaryen     43571
# 141           Arya Stark     41405
# 163     Balon IX Greyjoy     23530
# 172      Barristan Selmy     51501
# 315     Cersei Lannister     57402
# 382   Daenerys Targaryen     60681
# 384            Daeron II     22878
# 497         Eddard Stark     47247
# 563    Euron III Greyjoy     22127
# 848          Jaehaerys I     62517
# 853      Jaime Lannister     61110
# 901    Joffrey Baratheon     37045
# 930             Jon Snow     50589
# 1130            Maegor I     47018
# 1131            Maekar I     21060
#
#                                             roleInBooks  roleScore  \
# 8     [mentioned, mentioned, mentioned, mentioned, m...        4.5
# 9     [mentioned, mentioned, mentioned, mentioned, m...        3.5
# 10    [mentioned, mentioned, mentioned, mentioned, m...        4.5
# 11    [mentioned, mentioned, mentioned, mentioned, m...        5.5
# 16    [mentioned, appears, appears, appears, mention...        5.4
# 31    [mentioned, mentioned, mentioned, mentioned, m...        3.5
# 86    [mentioned, mentioned, mentioned, mentioned, m...        4.5
# 141            [appendix, POV, POV, POV, POV, POV, POV]        6.2
# 163   [mentioned, mentioned, appears, mentioned, men...        3.8
# 172   [mentioned, appears, appears, appears, mention...        5.4
# 315   [mentioned, appears, appears, appears, POV, PO...        5.9
# 382   [appendix, POV, POV, POV, mentioned, POV, ment...        5.2
# 384   [mentioned, mentioned, mentioned, mentioned, a...        4.2
# 497   [mentioned, POV, mentioned, mentioned, mention...        4.0
# 563   [mentioned, appendix, mentioned, mentioned, ap...        3.8
# 848   [mentioned, mentioned, mentioned, mentioned, m...        5.0
# 853        [mentioned, appears, appears, POV, POV, POV]        5.1
# 901   [mentioned, appears, appears, appears, mention...        4.4
# 930                       [POV, POV, POV, appears, POV]        4.8
# 1130  [mentioned, mentioned, mentioned, mentioned, m...        5.5
# 1131  [mentioned, appears, mentioned, mentioned, men...        4.3
#
#                                                  titles     score
# 8     [King of the Andals, the Rhoynar, and the Firs...  1.244787
# 9     [King of the Andals, the Rhoynar, and the Firs...  1.053087
# 10    [King of the Andals, the Rhoynar, and the Firs...  1.214104
# 11    [King of All Westeros, Shield of His People, K...  1.223701
# 16    [King of the Andals, the Rhoynar, and the Firs...  1.174563
# 31    [King of the Andals, the Rhoynar, and the Firs...  1.209435
# 86                                    [Princess, Queen]  1.040468
# 141                                          [Princess]  1.256024
# 163   [Lord of the Iron Islands, King of the Iron Is...  1.206317
# 172   [Ser, Lord Commander of the Kingsguard, Hand o...  1.224033
# 315   [Light of the West, Queen Dowager, Protector o...  1.354909
# 382   [Queen of Meereen, Queen of the Andals and the...  1.535370
# 384   [King of the Andals, the Rhoynar, and the Firs...  1.022251
# 497   [Lord of Winterfell, Warden of the North, Hand...  1.022876
# 563   [Iron King, King of the Isles and the North, K...  1.114010
# 848   [King of the Andals, the Rhoynar, and the Firs...  1.538499
# 853   [Ser, Lord Commander of the Kingsguard, Warden...  1.313066
# 901   [King of the Andals, the Rhoynar, and the Firs...  1.154774
# 930               [Lord Commander of the Night's Watch]  1.138553
# 1130  [King of the Andals, the Rhoynar, and the Firs...  1.395017
# 1131  [King of the Andals, the Rhoynar, and the Firs...  1.031778

# %%
df.loc[df['score'] > 1.0].sort_values(by = 'score', ascending = 0)
# Out:
#                                                 aliases  \
# 848           [The Conciliator, The Wise, The Old King]
# 382   [Daenerys Stormborn, Dany, The Unburnt, Mhysa,...
# 1130  [Maegor the Cruel, The Prince of Dragonstone, ...
# 315                                                None
# 853   [Kingslayer, The Lion of Lannister, The Young ...
# 141   [Arya Horseface, Arya Underfoot, Arry, Lumpyhe...
# 8     [Aegon the Younger, Aegon the Dragonbane, Aego...
# 172   [Barristan the Bold, Barristan the Old, Arstan...
# 11    [Aegon the Conqueror, Aegon the Dragonlord, Ae...
# 10                                 [Aegon the Unworthy]
# 31                            [The Mad King, King Scab]
# 163   [Balon the Brave, Balon the Blessed, Balon the...
# 16    [Aegon the Unlikely, Aegon the Fortunate, Egg,...
# 901   [Joffrey the Illborn, The Young Usurper, Aerys...
# 930   [Lord Snow, Ser Alliser's Bane, The Snow of Wi...
# 563       [Crow's Eye, Euron Crow's Eye, Euron Croweye]
# 9                  [Aegon the Elder, Aegon the Usurper]
# 86    [Good Queen Alysanne, The little maid, The oth...
# 1131                                        [The Anvil]
# 497                      [Ned, The Ned, The quiet wolf]
# 384             [Daeron the Good, Daeron the Falseborn]
#
#                                      books  \
# 848      [0, 0, 0, 0, 0, 0, 1, 3, 4, 5, 0]
# 382               [0, 1, 2, 3, 4, 5, 0, 0]
# 1130  [0, 0, 0, 0, 0, 0, 1, 2, 3, 4, 5, 0]
# 315               [0, 1, 2, 3, 4, 5, 0, 0]
# 853                  [0, 1, 2, 3, 4, 5, 0]
# 141               [0, 1, 2, 3, 4, 5, 0, 0]
# 8           [0, 0, 0, 0, 0, 1, 3, 4, 5, 0]
# 172               [0, 1, 2, 3, 4, 5, 0, 0]
# 11    [0, 0, 0, 0, 0, 0, 1, 2, 3, 4, 5, 0]
# 10          [0, 0, 0, 0, 1, 2, 3, 4, 5, 0]
# 31                [0, 1, 2, 3, 4, 5, 0, 0]
# 163               [0, 1, 2, 3, 4, 5, 0, 0]
# 16          [0, 0, 0, 0, 1, 2, 3, 4, 5, 0]
# 901               [0, 1, 2, 3, 4, 5, 0, 0]
# 930                     [1, 2, 3, 4, 5, 0]
# 563               [0, 1, 2, 3, 4, 5, 0, 0]
# 9                 [0, 0, 0, 0, 1, 3, 4, 0]
# 86          [0, 0, 0, 0, 0, 3, 4, 5, 0, 0]
# 1131           [0, 0, 0, 0, 1, 2, 4, 0, 0]
# 497               [0, 1, 2, 3, 4, 5, 0, 0]
# 384         [0, 0, 0, 0, 1, 2, 3, 4, 5, 0]
#
#                                                fullname  infoboxSize links  \
# 848           Jaehaerys Targaryen the First of His Name           81    []
# 382            Daenerys Targaryen the First of Her Name           81    []
# 1130             Maegor Targaryen the First of His Name           76    []
# 315                                                None           31    []
# 853                                                None           31    []
# 141                                                None           41    []
# 8                 Aegon Targaryen the Third of His Name           69    []
# 172                                                None           30    []
# 11                Aegon Targaryen the First of His Name           72    []
# 10               Aegon Targaryen the Fourth of His Name           79    []
# 31               Aerys Targaryen the Second of His Name           72    []
# 163   Balon Greyjoy, the Ninth of His Name Since the...           95    []
# 16                Aegon Targaryen the Fifth of His Name           69    []
# 901             Joffrey Baratheon the First of His Name           70    []
# 930                                                None           28    []
# 563   Euron Greyjoy, the Third of His Name Since the...           85    []
# 9                Aegon Targaryen the Second of His Name           69    []
# 86                                                 None           34    []
# 1131             Maekar Targaryen the First of His Name           69    []
# 497                                                None           32    []
# 384             Daeron Targaryen the Second of His Name           68    []
#
#                     name  pageSize  \
# 848          Jaehaerys I     62517
# 382   Daenerys Targaryen     60681
# 1130            Maegor I     47018
# 315     Cersei Lannister     57402
# 853      Jaime Lannister     61110
# 141           Arya Stark     41405
# 8              Aegon III     46334
# 172      Barristan Selmy     51501
# 11               Aegon I     27437
# 10              Aegon IV     35372
# 31              Aerys II     49289
# 163     Balon IX Greyjoy     23530
# 16               Aegon V     24048
# 901    Joffrey Baratheon     37045
# 930             Jon Snow     50589
# 563    Euron III Greyjoy     22127
# 9               Aegon II     35913
# 86    Alysanne Targaryen     43571
# 1131            Maekar I     21060
# 497         Eddard Stark     47247
# 384            Daeron II     22878
#
#                                             roleInBooks  roleScore  \
# 848   [mentioned, mentioned, mentioned, mentioned, m...        5.0
# 382   [appendix, POV, POV, POV, mentioned, POV, ment...        5.2
# 1130  [mentioned, mentioned, mentioned, mentioned, m...        5.5
# 315   [mentioned, appears, appears, appears, POV, PO...        5.9
# 853        [mentioned, appears, appears, POV, POV, POV]        5.1
# 141            [appendix, POV, POV, POV, POV, POV, POV]        6.2
# 8     [mentioned, mentioned, mentioned, mentioned, m...        4.5
# 172   [mentioned, appears, appears, appears, mention...        5.4
# 11    [mentioned, mentioned, mentioned, mentioned, m...        5.5
# 10    [mentioned, mentioned, mentioned, mentioned, m...        4.5
# 31    [mentioned, mentioned, mentioned, mentioned, m...        3.5
# 163   [mentioned, mentioned, appears, mentioned, men...        3.8
# 16    [mentioned, appears, appears, appears, mention...        5.4
# 901   [mentioned, appears, appears, appears, mention...        4.4
# 930                       [POV, POV, POV, appears, POV]        4.8
# 563   [mentioned, appendix, mentioned, mentioned, ap...        3.8
# 9     [mentioned, mentioned, mentioned, mentioned, m...        3.5
# 86    [mentioned, mentioned, mentioned, mentioned, m...        4.5
# 1131  [mentioned, appears, mentioned, mentioned, men...        4.3
# 497   [mentioned, POV, mentioned, mentioned, mention...        4.0
# 384   [mentioned, mentioned, mentioned, mentioned, a...        4.2
#
#                                                  titles     score
# 848   [King of the Andals, the Rhoynar, and the Firs...  1.538499
# 382   [Queen of Meereen, Queen of the Andals and the...  1.535370
# 1130  [King of the Andals, the Rhoynar, and the Firs...  1.395017
# 315   [Light of the West, Queen Dowager, Protector o...  1.354909
# 853   [Ser, Lord Commander of the Kingsguard, Warden...  1.313066
# 141                                          [Princess]  1.256024
# 8     [King of the Andals, the Rhoynar, and the Firs...  1.244787
# 172   [Ser, Lord Commander of the Kingsguard, Hand o...  1.224033
# 11    [King of All Westeros, Shield of His People, K...  1.223701
# 10    [King of the Andals, the Rhoynar, and the Firs...  1.214104
# 31    [King of the Andals, the Rhoynar, and the Firs...  1.209435
# 163   [Lord of the Iron Islands, King of the Iron Is...  1.206317
# 16    [King of the Andals, the Rhoynar, and the Firs...  1.174563
# 901   [King of the Andals, the Rhoynar, and the Firs...  1.154774
# 930               [Lord Commander of the Night's Watch]  1.138553
# 563   [Iron King, King of the Isles and the North, K...  1.114010
# 9     [King of the Andals, the Rhoynar, and the Firs...  1.053087
# 86                                    [Princess, Queen]  1.040468
# 1131  [King of the Andals, the Rhoynar, and the Firs...  1.031778
# 497   [Lord of Winterfell, Warden of the North, Hand...  1.022876
# 384   [King of the Andals, the Rhoynar, and the Firs...  1.022251
